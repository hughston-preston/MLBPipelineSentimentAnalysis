# %%
# !pip install --upgrade pip
# !pip install textblob

from textblob import TextBlob

import pandas as pd

import requests

import json
# Out:
# Requirement already up-to-date: pip in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (20.0.2)
# Requirement already satisfied: textblob in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from textblob) (3.3)
# Requirement already satisfied: six in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nltk>=3.1->textblob) (1.11.0)

# %%
#The 2019 MLB Team Top 30s

mlb_json_id_url = 'http://m.mlb.com/gen/players/prospects/2019/playerProspects.json'
response = requests.get(mlb_json_id_url)
response.status_code
team_key = ['ana', 'hou', 'oak', 'tor', 'atl', 'mil', 'stl', 'chc', 'ari', 'la', 'sf', 'cle', 'sea', 'mia', 'nym', 'was', 'bal', 'sd', 'phi', 'pit', 'tex', 'tb', 'cin', 'bos', 'col', 'kc', 'det', 'min', 'cws', 'nyy']
all_json = response.json()
team_prospect_list_2019 = []
json_team_code_list = []
for i in team_key:
    team_prospect_list_2019 = all_json['prospect_players'][i]
    json_team_code_list.append(team_prospect_list_2019)
json_team_code_list

team_player_ids_2019 = []
team_player_ranks_2019 = []
team_player_first_name_2019 = []
team_player_last_name_2019 = []
team_player_position_2019 = []
for j in json_team_code_list:
    for i in j:
        team_player_id_2019 = str(i['player_id'])
        team_player_ids_2019.append(team_player_id_2019)                      
        team_rank_2019 = i["rank"]
        team_player_ranks_2019.append(team_rank_2019)
        team_first_name_2019 = i["player_first_name"]
        team_player_first_name_2019.append(team_first_name_2019)
        team_last_name_2019 = i["player_last_name"]
        team_player_last_name_2019.append(team_last_name_2019)
        team_position_2019 = i["position"]
        team_player_position_2019.append(team_position_2019)
        team_player_id_data_2019 = {'First Name' : team_player_first_name_2019, 'Last Name' : team_player_last_name_2019, 'Player ID' : team_player_ids_2019, 'Position' : team_player_position_2019, 'Player Rank' : team_player_ranks_2019}

team_player_id_dataframe_2019 = pd.DataFrame(team_player_id_data_2019)
team_player_id_dataframe_2019 = pd.DataFrame(team_player_id_data_2019)
json_team_code_list
# Out:
# [[{'prospect_year': '2019',
#    'player_id': 666176,
#    'player_first_name': 'Jo',
#    'player_last_name': 'Adell',
#    'rank': 1,
#    'position': 'OF',
#    'preseason100': 14,
#    'preseason20': 1,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/8/4/0/301900840/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/9/0/309679090/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/9/0/309679090/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/9/0/309679090/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/9/0/309679090/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669016,
#    'player_first_name': 'Brandon',
#    'player_last_name': 'Marsh',
#    'rank': 2,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 3,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/2/7/4/307247274/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/2/7/4/307247274/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/7/4/307247274/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/7/4/307247274/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/7/4/307247274/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 677941,
#    'player_first_name': 'Jordyn',
#    'player_last_name': 'Adams',
#    'rank': 3,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 6,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/7/1/6/285298716/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/8/0/309294580/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/8/0/309294580/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/8/0/309294580/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/8/0/309294580/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669236,
#    'player_first_name': 'Jeremiah',
#    'player_last_name': 'Jackson',
#    'rank': 4,
#    'position': 'SS/2B',
#    'preseason100': '',
#    'preseason20': 9,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/9/8/0/285298980/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/2/6/309006526/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/2/6/309006526/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/2/6/309006526/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/2/6/309006526/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 663330,
#    'player_first_name': 'Jahmai',
#    'player_last_name': 'Jones',
#    'rank': 5,
#    'position': '2B',
#    'preseason100': '',
#    'preseason20': 4,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/5/4/4/302063544/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/4/4/302063544/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/4/4/302063544/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/4/4/302063544/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/4/4/302063544/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 677347,
#    'player_first_name': 'Kyren',
#    'player_last_name': 'Paris',
#    'rank': 6,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/8/7/0/307427870/cuts/62x75/cut.JPG',
#    'thumb124x150': '/assets/images/8/7/0/307427870/cuts/124x150/cut.JPG',
#    'photo180x218': '/assets/images/8/7/0/307427870/cuts/180x218/cut.JPG',
#    'photo360x436': '/assets/images/8/7/0/307427870/cuts/360x436/cut.JPG'},
#   {'prospect_year': '2019',
#    'player_id': 677610,
#    'player_first_name': "D'Shawn",
#    'player_last_name': 'Knowles',
#    'rank': 7,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 10,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/6/4/8/282674648/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/6/7/6/309006676/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/7/6/309006676/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/7/6/309006676/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/7/6/309006676/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 663776,
#    'player_first_name': 'Patrick',
#    'player_last_name': 'Sandoval',
#    'rank': 8,
#    'position': 'LHP',
#    'preseason100': '',
#    'preseason20': 12,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/5/6/0/290616560/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/8/0/311065080/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/8/0/311065080/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/8/0/311065080/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/8/0/311065080/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 667755,
#    'player_first_name': 'Jose',
#    'player_last_name': 'Soriano',
#    'rank': 9,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 13,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/8/8/6/287459886/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/8/8/6/287459886/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/8/6/287459886/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/8/6/287459886/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/8/6/287459886/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 677575,
#    'player_first_name': 'Trent',
#    'player_last_name': 'Deveaux',
#    'rank': 10,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 17,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/4/6/0/265805460/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/6/0/265805460/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/6/0/265805460/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/6/0/265805460/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/6/0/265805460/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 686799,
#    'player_first_name': 'Jack',
#    'player_last_name': 'Kochanowicz',
#    'rank': 11,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/3/0/0/300788300/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/0/0/300788300/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/0/0/300788300/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/0/0/300788300/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/0/0/300788300/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669443,
#    'player_first_name': 'Aaron',
#    'player_last_name': 'Hernandez',
#    'rank': 12,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 20,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/6/8/2/303863682/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/4/8/307994448/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/4/8/307994448/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/4/8/307994448/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/4/8/307994448/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669735,
#    'player_first_name': 'Chris',
#    'player_last_name': 'Rodriguez',
#    'rank': 13,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 11,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/0/1/4/266071014/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/1/4/309007014/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/1/4/309007014/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/1/4/309007014/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/1/4/309007014/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 670869,
#    'player_first_name': 'Livan',
#    'player_last_name': 'Soto',
#    'rank': 14,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': 19,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/3/0/8/287460308/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/9/5/8/309013958/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/9/5/8/309013958/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/9/5/8/309013958/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/9/5/8/309013958/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 666668,
#    'player_first_name': 'Hector',
#    'player_last_name': 'Yan',
#    'rank': 15,
#    'position': 'LHP',
#    'preseason100': '',
#    'preseason20': 'NR',
#    'team_file_code': 'ANA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/2/8/8/308952288/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/8/8/308952288/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/8/8/308952288/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/8/8/308952288/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 661383,
#    'player_first_name': 'Oliver',
#    'player_last_name': 'Ortega',
#    'rank': 16,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'LAA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/2/5/8/309310258/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/5/8/309310258/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/5/8/309310258/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/5/8/309310258/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 666766,
#    'player_first_name': 'Stiward',
#    'player_last_name': 'Aquino',
#    'rank': 17,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 18,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/1/2/8/266912128/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/2/8/266912128/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/2/8/266912128/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/2/8/266912128/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/2/8/266912128/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 665120,
#    'player_first_name': 'Jared',
#    'player_last_name': 'Walsh',
#    'rank': 18,
#    'position': '1B/OF/LHP',
#    'preseason100': '',
#    'preseason20': 21,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/3/8/0/303862380/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/9/1/0/311064910/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/9/1/0/311064910/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/9/1/0/311064910/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/9/1/0/311064910/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 670867,
#    'player_first_name': 'Kevin',
#    'player_last_name': 'Maitan',
#    'rank': 19,
#    'position': 'INF',
#    'preseason100': '',
#    'preseason20': 15,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/6/4/2/266197642/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/8/0/309509080/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/8/0/309509080/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/8/0/309509080/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/8/0/309509080/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 682643,
#    'player_first_name': 'Alexander',
#    'player_last_name': 'Ramirez',
#    'rank': 20,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/0/1/0/308637010/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/6/4/6/309649646/cuts/62x75/cut.JPG',
#    'thumb124x150': '/assets/images/6/4/6/309649646/cuts/124x150/cut.JPG',
#    'photo180x218': '/assets/images/6/4/6/309649646/cuts/180x218/cut.JPG',
#    'photo360x436': '/assets/images/6/4/6/309649646/cuts/360x436/cut.JPG'},
#   {'prospect_year': '2019',
#    'player_id': 660844,
#    'player_first_name': 'Leonardo',
#    'player_last_name': 'Rivas',
#    'rank': 21,
#    'position': 'SS/2B',
#    'preseason100': '',
#    'preseason20': 27,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/6/1/4/302065614/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/9/4/2/309007942/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/9/4/2/309007942/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/9/4/2/309007942/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/9/4/2/309007942/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 641684,
#    'player_first_name': 'Michael',
#    'player_last_name': 'Hermosillo',
#    'rank': 22,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 16,
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/5/8/2/295106582/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/2/0/4/311065204/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/0/4/311065204/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/0/4/311065204/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/0/4/311065204/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 673820,
#    'player_first_name': 'Robinson',
#    'player_last_name': 'Pina',
#    'rank': 23,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'LAA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/7/6/6/309310766/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/7/6/6/309310766/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/7/6/6/309310766/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/7/6/6/309310766/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 691186,
#    'player_first_name': 'Arol',
#    'player_last_name': 'Vera',
#    'rank': 24,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'LAA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/3/1/8/309311318/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/1/8/309311318/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/1/8/309311318/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/1/8/309311318/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 680721,
#    'player_first_name': 'William',
#    'player_last_name': 'Holmes',
#    'rank': 25,
#    'position': 'RHP/OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/3/4/0/305704340/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/4/0/305704340/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/4/0/305704340/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/4/0/305704340/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/4/0/305704340/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 668831,
#    'player_first_name': 'Garrett',
#    'player_last_name': 'Stallings',
#    'rank': 26,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/2/2/0/310066220/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/2/2/0/310066220/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/2/0/310066220/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/2/0/310066220/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/2/0/310066220/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 691269,
#    'player_first_name': 'Adrian',
#    'player_last_name': 'Placencia',
#    'rank': 27,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/7/0/2/312076702/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/7/0/2/312076702/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/7/0/2/312076702/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/7/0/2/312076702/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 678636,
#    'player_first_name': 'Orlando',
#    'player_last_name': 'Martinez',
#    'rank': 28,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '/assets/images/3/6/2/312140362/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/6/2/312140362/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/6/2/312140362/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/6/2/312140362/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/6/2/312140362/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 682992,
#    'player_first_name': 'Erik',
#    'player_last_name': 'Rivera',
#    'rank': 29,
#    'position': 'LHP/OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/4/7/6/312430476/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/7/6/312430476/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/7/6/312430476/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/7/6/312430476/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 682661,
#    'player_first_name': 'Jose',
#    'player_last_name': 'Bonilla',
#    'rank': 30,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'ANA',
#    'thumb': '',
#    'thumb62x75': '/assets/images/7/7/2/312501772/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/7/7/2/312501772/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/7/7/2/312501772/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/7/7/2/312501772/cuts/360x436/cut.jpg'}],
#  [{'prospect_year': '2019',
#    'player_id': 666215,
#    'player_first_name': 'Forrest',
#    'player_last_name': 'Whitley',
#    'rank': 1,
#    'position': 'RHP',
#    'preseason100': 7,
#    'preseason20': 1,
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/3/2/8/309957328/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/2/8/309957328/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/2/8/309957328/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/2/8/309957328/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 671265,
#    'player_first_name': 'Freudis',
#    'player_last_name': 'Nova',
#    'rank': 2,
#    'position': 'INF',
#    'preseason100': '',
#    'preseason20': 7,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/7/9/2/302059792/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/4/4/309017044/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/4/4/309017044/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/4/4/309017044/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/4/4/309017044/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 686676,
#    'player_first_name': 'Korey',
#    'player_last_name': 'Lee',
#    'rank': 3,
#    'position': 'C',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/6/4/0/309554640/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/4/0/309554640/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/4/0/309554640/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/4/0/309554640/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 650556,
#    'player_first_name': 'Bryan',
#    'player_last_name': 'Abreu',
#    'rank': 4,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 8,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/6/1/2/311080612/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/6/1/2/311080612/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/1/2/311080612/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/1/2/311080612/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/1/2/311080612/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 647351,
#    'player_first_name': 'Abraham',
#    'player_last_name': 'Toro',
#    'rank': 5,
#    'position': '3B',
#    'preseason100': '',
#    'preseason20': 23,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/4/5/2/302062452/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/5/8/310468158/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/5/8/310468158/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/5/8/310468158/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/5/8/310468158/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 663959,
#    'player_first_name': 'Tyler',
#    'player_last_name': 'Ivey',
#    'rank': 6,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 17,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/5/3/0/307067530/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/3/0/307067530/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/3/0/307067530/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/3/0/307067530/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/3/0/307067530/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 685084,
#    'player_first_name': 'Jordan',
#    'player_last_name': 'Brewer',
#    'rank': 7,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/6/7/8/311061678/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/7/8/311061678/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/7/8/311061678/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/7/8/311061678/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 665161,
#    'player_first_name': 'Jeremy',
#    'player_last_name': 'Pena',
#    'rank': 8,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': 27,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/3/9/2/295409392/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/4/2/308981342/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/4/2/308981342/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/4/2/308981342/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/4/2/308981342/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 664299,
#    'player_first_name': 'Cristian',
#    'player_last_name': 'Javier',
#    'rank': 9,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/8/5/4/306937854/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/5/2/310725552/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/5/2/310725552/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/5/2/310725552/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/5/2/310725552/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 656232,
#    'player_first_name': 'Brandon',
#    'player_last_name': 'Bielak',
#    'rank': 10,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 15,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/7/1/0/291676710/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/3/2/308980532/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/3/2/308980532/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/3/2/308980532/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/3/2/308980532/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 664353,
#    'player_first_name': 'Jose',
#    'player_last_name': 'Urquidy',
#    'rank': 11,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/2/8/0/309296280/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/8/0/309296280/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/8/0/309296280/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/8/0/309296280/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 666197,
#    'player_first_name': 'Grae',
#    'player_last_name': 'Kessinger',
#    'rank': 12,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/2/4/8/309255248/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/4/8/309255248/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/4/8/309255248/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/4/8/309255248/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 660600,
#    'player_first_name': 'Enoli',
#    'player_last_name': 'Paredes',
#    'rank': 13,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 28,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/0/8/4/311081084/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/8/4/311081084/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/8/4/311081084/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/8/4/311081084/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/8/4/311081084/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 596117,
#    'player_first_name': 'Garrett',
#    'player_last_name': 'Stubbs',
#    'rank': 14,
#    'position': 'C',
#    'preseason100': '',
#    'preseason20': 14,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/6/7/2/311080672/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/6/7/2/311080672/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/7/2/311080672/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/7/2/311080672/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/7/2/311080672/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 670919,
#    'player_first_name': 'Luis',
#    'player_last_name': 'Santana',
#    'rank': 15,
#    'position': '2B/3B',
#    'preseason100': '',
#    'preseason20': 21,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/3/0/0/304022300/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/9/3/2/307991932/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/9/3/2/307991932/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/9/3/2/307991932/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/9/3/2/307991932/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669008,
#    'player_first_name': 'Ronnie',
#    'player_last_name': 'Dawson',
#    'rank': 16,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 13,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/8/4/2/302061842/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/8/4/2/302061842/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/4/2/302061842/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/4/2/302061842/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/4/2/302061842/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 656695,
#    'player_first_name': 'J.J.',
#    'player_last_name': 'Matijevic',
#    'rank': 17,
#    'position': '1B/OF',
#    'preseason100': '',
#    'preseason20': 22,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/0/9/4/302062094/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/4/0/309016340/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/4/0/309016340/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/4/0/309016340/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/4/0/309016340/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 656981,
#    'player_first_name': 'Peter',
#    'player_last_name': 'Solomon',
#    'rank': 18,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 12,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/3/9/6/304021396/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/8/2/308980382/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/8/2/308980382/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/8/2/308980382/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/8/2/308980382/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 672810,
#    'player_first_name': 'Jairo',
#    'player_last_name': 'Solis',
#    'rank': 19,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 19,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/4/4/6/287451446/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/4/6/287451446/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/4/6/287451446/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/4/6/287451446/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/4/6/287451446/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 683145,
#    'player_first_name': 'Colin',
#    'player_last_name': 'Barber',
#    'rank': 20,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/1/9/0/307265190/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/9/0/307265190/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/9/0/307265190/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/9/0/307265190/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 660494,
#    'player_first_name': 'Rogelio',
#    'player_last_name': 'Armenteros',
#    'rank': 21,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 24,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/2/2/0/311081220/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/2/2/0/311081220/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/2/0/311081220/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/2/0/311081220/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/2/0/311081220/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 686613,
#    'player_first_name': 'Hunter',
#    'player_last_name': 'Brown',
#    'rank': 22,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/2/2/4/309310224/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/2/4/309310224/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/2/4/309310224/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/2/4/309310224/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 681869,
#    'player_first_name': 'Shawn',
#    'player_last_name': 'Dubin',
#    'rank': 23,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/4/6/2/310957462/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/6/2/310957462/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/6/2/310957462/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/6/2/310957462/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 677315,
#    'player_first_name': 'Jayson',
#    'player_last_name': 'Schroeder',
#    'rank': 24,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 18,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/1/0/0/304558100/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/0/0/304558100/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/0/0/304558100/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/0/0/304558100/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/0/0/304558100/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 670550,
#    'player_first_name': 'Nivaldo',
#    'player_last_name': 'Rodriguez',
#    'rank': 25,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/4/9/6/308061496/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/9/6/308061496/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/9/6/308061496/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/9/6/308061496/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 666672,
#    'player_first_name': 'Jojanse',
#    'player_last_name': 'Torres',
#    'rank': 26,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/5/9/2/312185592/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/9/2/312185592/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/9/2/312185592/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/9/2/312185592/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/9/2/312185592/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 680244,
#    'player_first_name': 'Ross',
#    'player_last_name': 'Adolph',
#    'rank': 27,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 30,
#    'team_file_code': 'HOU',
#    'thumb': '/assets/images/6/8/8/304025688/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/0/2/311062002/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/0/2/311062002/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/0/2/311062002/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/0/2/311062002/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 622100,
#    'player_first_name': 'Taylor',
#    'player_last_name': 'Jones',
#    'rank': 28,
#    'position': '1B/OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/7/4/2/309341742/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/7/4/2/309341742/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/7/4/2/309341742/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/7/4/2/309341742/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 677651,
#    'player_first_name': 'Luis',
#    'player_last_name': 'Garcia',
#    'rank': 29,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/7/0/0/309925700/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/7/0/0/309925700/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/7/0/0/309925700/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/7/0/0/309925700/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 673277,
#    'player_first_name': 'Jose Alberto',
#    'player_last_name': 'Rivera',
#    'rank': 30,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'HOU',
#    'thumb': '',
#    'thumb62x75': '/assets/images/2/4/4/309590244/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/4/4/309590244/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/4/4/309590244/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/4/4/309590244/cuts/360x436/cut.jpg'}],
#  [{'prospect_year': '2019',
#    'player_id': 666200,
#    'player_first_name': 'Jesus',
#    'player_last_name': 'Luzardo',
#    'rank': 1,
#    'position': 'LHP',
#    'preseason100': 12,
#    'preseason20': 1,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/0/4/2/302111042/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/7/6/2/310687762/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/7/6/2/310687762/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/7/6/2/310687762/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/7/6/2/310687762/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 640462,
#    'player_first_name': 'A.J.',
#    'player_last_name': 'Puk',
#    'rank': 2,
#    'position': 'LHP',
#    'preseason100': 42,
#    'preseason20': 2,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/4/3/8/310687438/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/3/8/310687438/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/3/8/310687438/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/3/8/310687438/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/3/8/310687438/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669221,
#    'player_first_name': 'Sean',
#    'player_last_name': 'Murphy',
#    'rank': 3,
#    'position': 'C',
#    'preseason100': 45,
#    'preseason20': 3,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/7/3/4/302111734/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/2/8/310666028/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/2/8/310666028/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/2/8/310666028/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/2/8/310666028/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 622761,
#    'player_first_name': 'Jorge',
#    'player_last_name': 'Mateo',
#    'rank': 4,
#    'position': 'SS/2B',
#    'preseason100': '',
#    'preseason20': 8,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/8/6/4/306983864/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/6/4/306983864/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/6/4/306983864/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/6/4/306983864/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 691188,
#    'player_first_name': 'Robert',
#    'player_last_name': 'Puason',
#    'rank': 5,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/0/8/2/309342082/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/8/2/309342082/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/8/2/309342082/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/8/2/309342082/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669397,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Allen',
#    'rank': 6,
#    'position': 'SS/2B',
#    'preseason100': '',
#    'preseason20': 15,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/6/7/0/302113670/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/2/2/8/308942228/cuts/62x75/cut.jpeg',
#    'thumb124x150': '/assets/images/2/2/8/308942228/cuts/124x150/cut.jpeg',
#    'photo180x218': '/assets/images/2/2/8/308942228/cuts/180x218/cut.jpeg',
#    'photo360x436': '/assets/images/2/2/8/308942228/cuts/360x436/cut.jpeg'},
#   {'prospect_year': '2019',
#    'player_id': 669722,
#    'player_first_name': 'Logan',
#    'player_last_name': 'Davidson',
#    'rank': 7,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/3/5/8/310688358/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/5/8/310688358/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/5/8/310688358/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/5/8/310688358/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/5/8/310688358/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 641914,
#    'player_first_name': 'Sheldon',
#    'player_last_name': 'Neuse',
#    'rank': 8,
#    'position': '3B',
#    'preseason100': '',
#    'preseason20': 9,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/8/8/2/310668882/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/8/2/310668882/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/8/2/310668882/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/8/2/310668882/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 642456,
#    'player_first_name': 'Luis',
#    'player_last_name': 'Barrera',
#    'rank': 9,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 13,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/0/5/2/308021052/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/5/2/308021052/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/5/2/308021052/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/5/2/308021052/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 675648,
#    'player_first_name': 'Austin',
#    'player_last_name': 'Beck',
#    'rank': 10,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 5,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/4/0/8/311171408/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/0/8/311171408/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/0/8/311171408/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/0/8/311171408/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 670860,
#    'player_first_name': 'Lazaro',
#    'player_last_name': 'Armenteros',
#    'rank': 11,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 4,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/4/8/6/308942486/cuts/62x75/cut.jpeg',
#    'thumb124x150': '/assets/images/4/8/6/308942486/cuts/124x150/cut.jpeg',
#    'photo180x218': '/assets/images/4/8/6/308942486/cuts/180x218/cut.jpeg',
#    'photo360x436': '/assets/images/4/8/6/308942486/cuts/360x436/cut.jpeg'},
#   {'prospect_year': '2019',
#    'player_id': 641726,
#    'player_first_name': 'Daulton',
#    'player_last_name': 'Jefferies',
#    'rank': 12,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 14,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/7/4/6/287455746/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/2/9/2/308965292/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/2/9/2/308965292/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/2/9/2/308965292/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/2/9/2/308965292/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 621076,
#    'player_first_name': 'James',
#    'player_last_name': 'Kaprielian',
#    'rank': 13,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 6,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/7/6/0/303357760/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/2/0/310354320/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/2/0/310354320/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/2/0/310354320/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/2/0/310354320/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 656550,
#    'player_first_name': 'Grant',
#    'player_last_name': 'Holmes',
#    'rank': 14,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 12,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/5/8/4/302113584/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/5/8/4/302113584/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/8/4/302113584/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/8/4/302113584/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/8/4/302113584/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 663369,
#    'player_first_name': 'Jeremy',
#    'player_last_name': 'Eierman',
#    'rank': 15,
#    'position': 'SS/2B',
#    'preseason100': '',
#    'preseason20': 10,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/5/9/2/285156592/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/8/8/308942488/cuts/62x75/cut.jpeg',
#    'thumb124x150': '/assets/images/4/8/8/308942488/cuts/124x150/cut.jpeg',
#    'photo180x218': '/assets/images/4/8/8/308942488/cuts/180x218/cut.jpeg',
#    'photo360x436': '/assets/images/4/8/8/308942488/cuts/360x436/cut.jpeg'},
#   {'prospect_year': '2019',
#    'player_id': 621450,
#    'player_first_name': 'Skye',
#    'player_last_name': 'Bolt',
#    'rank': 16,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 19,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/8/9/4/302114894/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/8/4/4/309120844/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/4/4/309120844/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/4/4/309120844/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/4/4/309120844/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 656364,
#    'player_first_name': 'Greg',
#    'player_last_name': 'Deichmann',
#    'rank': 17,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 11,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/8/6/0/308020860/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/6/0/308020860/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/6/0/308020860/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/6/0/308020860/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 668832,
#    'player_first_name': 'Kyle',
#    'player_last_name': 'McCann',
#    'rank': 18,
#    'position': 'C',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/3/7/0/310688370/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/7/0/310688370/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/7/0/310688370/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/7/0/310688370/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/7/0/310688370/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 672478,
#    'player_first_name': 'Jordan',
#    'player_last_name': 'Diaz',
#    'rank': 19,
#    'position': '3B',
#    'preseason100': '',
#    'preseason20': 26,
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/7/8/6/304018786/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/2/6/308261426/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/2/6/308261426/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/2/6/308261426/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/2/6/308261426/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 666121,
#    'player_first_name': 'Tyler',
#    'player_last_name': 'Baum',
#    'rank': 20,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/9/9/0/310687990/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/9/9/0/310687990/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/9/9/0/310687990/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/9/9/0/310687990/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/9/9/0/310687990/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 641680,
#    'player_first_name': 'Jonah',
#    'player_last_name': 'Heim',
#    'rank': 21,
#    'position': 'C',
#    'preseason100': '',
#    'preseason20': 29,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/6/4/0/309120640/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/4/0/309120640/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/4/0/309120640/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/4/0/309120640/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 642002,
#    'player_first_name': 'Buddy',
#    'player_last_name': 'Reed',
#    'rank': 22,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '17 - SD',
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/4/4/2/306230442/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/9/2/308238192/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/9/2/308238192/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/9/2/308238192/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/9/2/308238192/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 641709,
#    'player_first_name': 'Brian',
#    'player_last_name': 'Howard',
#    'rank': 23,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 21,
#    'team_file_code': 'OAK',
#    'thumb': '',
#    'thumb62x75': '/assets/images/0/0/2/308022002/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/0/2/308022002/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/0/2/308022002/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/0/2/308022002/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 686452,
#    'player_first_name': 'Drew',
#    'player_last_name': 'Millas',
#    'rank': 24,
#    'position': 'C',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'OAK',
#    'thumb': '/assets/images/1/9/4/309411194/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/9/4/309411194/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/9/4/309411194/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/9/4/309411194/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/9/4/309411194/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 670161,
#    'player_first_name': 'Parker',
#    'player_last_name': 'Dunshee',
#    'rank': 25,
#    'position': 'RHP',
# ...
#    'photo180x218': '/assets/images/0/6/6/309341066/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/6/6/309341066/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 664314,
#    'player_first_name': 'Estevan',
#    'player_last_name': 'Florial',
#    'rank': 3,
#    'position': 'OF',
#    'preseason100': 57,
#    'preseason20': 1,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/8/7/0/301905870/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/8/7/0/301905870/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/7/0/301905870/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/7/0/301905870/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/7/0/301905870/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 661563,
#    'player_first_name': 'Luis',
#    'player_last_name': 'Gil',
#    'rank': 4,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 13,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/4/3/4/306430434/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/6/2/6/311157626/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/2/6/311157626/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/2/6/311157626/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/2/6/311157626/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 657376,
#    'player_first_name': 'Clarke',
#    'player_last_name': 'Schmidt',
#    'rank': 5,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 5,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/0/6/4/302105064/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/2/2/311158122/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/2/2/311158122/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/2/2/311158122/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/2/2/311158122/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 656061,
#    'player_first_name': 'Albert',
#    'player_last_name': 'Abreu',
#    'rank': 6,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 3,
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/4/4/8/308022448/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/4/8/308022448/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/4/8/308022448/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/4/8/308022448/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 672782,
#    'player_first_name': 'Yoendrys',
#    'player_last_name': 'Gomez',
#    'rank': 7,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 27,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/1/5/8/304094158/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/5/8/304094158/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/5/8/304094158/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/5/8/304094158/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/5/8/304094158/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 678011,
#    'player_first_name': 'Anthony',
#    'player_last_name': 'Seigler',
#    'rank': 8,
#    'position': 'C',
#    'preseason100': '',
#    'preseason20': 6,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/4/4/2/302104442/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/3/0/308977130/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/3/0/308977130/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/3/0/308977130/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/3/0/308977130/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 677592,
#    'player_first_name': 'Everson',
#    'player_last_name': 'Pereira',
#    'rank': 9,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 7,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/1/2/2/287443122/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/3/0/311158430/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/3/0/311158430/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/3/0/311158430/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/3/0/311158430/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 683011,
#    'player_first_name': 'Anthony',
#    'player_last_name': 'Volpe',
#    'rank': 10,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/5/1/0/306724510/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/1/0/306724510/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/1/0/306724510/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/1/0/306724510/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 679737,
#    'player_first_name': 'Antonio',
#    'player_last_name': 'Cabello',
#    'rank': 11,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 9,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/6/3/6/287908636/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/6/3/6/287908636/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/3/6/287908636/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/3/6/287908636/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/3/6/287908636/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 672710,
#    'player_first_name': 'Roansy',
#    'player_last_name': 'Contreras',
#    'rank': 12,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 10,
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/7/2/8/308022728/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/7/2/8/308022728/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/7/2/8/308022728/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/7/2/8/308022728/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669805,
#    'player_first_name': 'Alexander',
#    'player_last_name': 'Vizcaino',
#    'rank': 13,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/5/6/0/311158560/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/5/6/0/311158560/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/5/6/0/311158560/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/5/6/0/311158560/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 656793,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Nelson',
#    'rank': 14,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 11,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/1/4/2/302108142/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/4/2/302108142/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/4/2/302108142/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/4/2/302108142/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/4/2/302108142/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 663986,
#    'player_first_name': 'Trevor',
#    'player_last_name': 'Stephan',
#    'rank': 15,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 8,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/9/2/8/304094928/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/9/2/8/304094928/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/9/2/8/304094928/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/9/2/8/304094928/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/9/2/8/304094928/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 674674,
#    'player_first_name': 'T.J.',
#    'player_last_name': 'Sikkema',
#    'rank': 16,
#    'position': 'LHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/3/9/6/306424396/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/0/7/4/309293074/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/7/4/309293074/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/7/4/309293074/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/7/4/309293074/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 682634,
#    'player_first_name': 'Kevin',
#    'player_last_name': 'Alcantara',
#    'rank': 17,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/1/0/2/310312102/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/0/2/310312102/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/0/2/310312102/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/0/2/310312102/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 669701,
#    'player_first_name': 'Josh',
#    'player_last_name': 'Smith',
#    'rank': 18,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/3/1/0/311158310/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/1/0/311158310/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/1/0/311158310/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/1/0/311158310/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 650633,
#    'player_first_name': 'Michael',
#    'player_last_name': 'King',
#    'rank': 19,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 12,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/3/2/8/294542328/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/3/2/8/294542328/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/3/2/8/294542328/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/3/2/8/294542328/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/3/2/8/294542328/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 665622,
#    'player_first_name': 'Luis',
#    'player_last_name': 'Medina',
#    'rank': 20,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 14,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/4/4/6/302105446/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/4/4/6/302105446/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/4/4/6/302105446/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/4/4/6/302105446/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/4/4/6/302105446/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 677007,
#    'player_first_name': 'Josh',
#    'player_last_name': 'Breaux',
#    'rank': 21,
#    'position': 'C',
#    'preseason100': '',
#    'preseason20': 15,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/5/5/4/302106554/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/2/0/306862120/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/2/0/306862120/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/2/0/306862120/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/2/0/306862120/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 680685,
#    'player_first_name': 'Ryder',
#    'player_last_name': 'Green',
#    'rank': 22,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 24,
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/1/9/6/308409196/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/9/6/308409196/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/9/6/308409196/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/9/6/308409196/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 681464,
#    'player_first_name': 'Frank',
#    'player_last_name': 'German',
#    'rank': 23,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 21,
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/1/7/0/308023170/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/7/0/308023170/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/7/0/308023170/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/7/0/308023170/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 678803,
#    'player_first_name': 'Anthony',
#    'player_last_name': 'Garcia',
#    'rank': 24,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': 22,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/6/1/8/300941618/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/6/1/8/300941618/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/1/8/300941618/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/1/8/300941618/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/1/8/300941618/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 675986,
#    'player_first_name': 'Canaan',
#    'player_last_name': 'Smith',
#    'rank': 25,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/0/1/4/311159014/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/0/1/4/311159014/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/0/1/4/311159014/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/0/1/4/311159014/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 664337,
#    'player_first_name': 'Miguel',
#    'player_last_name': 'Yajure',
#    'rank': 26,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/1/1/2/310726112/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/1/2/310726112/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/1/2/310726112/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/1/2/310726112/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 676477,
#    'player_first_name': 'Garrett',
#    'player_last_name': 'Whitlock',
#    'rank': 27,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 16,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/6/9/2/302105692/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/4/0/308239140/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/4/0/308239140/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/4/0/308239140/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/4/0/308239140/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 682640,
#    'player_first_name': 'Osiel',
#    'player_last_name': 'Rodriguez',
#    'rank': 28,
#    'position': 'RHP',
#    'preseason100': '',
#    'preseason20': 18,
#    'team_file_code': 'NYY',
#    'thumb': '/assets/images/1/3/2/285305132/cuts/74x74/cut.jpg',
#    'thumb62x75': '/assets/images/1/3/2/285305132/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/1/3/2/285305132/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/1/3/2/285305132/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/1/3/2/285305132/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 672724,
#    'player_first_name': 'Oswald',
#    'player_last_name': 'Peraza',
#    'rank': 29,
#    'position': 'SS',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/8/7/0/309370870/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/8/7/0/309370870/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/8/7/0/309370870/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/8/7/0/309370870/cuts/360x436/cut.jpg'},
#   {'prospect_year': '2019',
#    'player_id': 663604,
#    'player_first_name': 'Brandon',
#    'player_last_name': 'Lockridge',
#    'rank': 30,
#    'position': 'OF',
#    'preseason100': '',
#    'preseason20': '',
#    'team_file_code': 'NYY',
#    'thumb': '',
#    'thumb62x75': '/assets/images/6/8/4/310240684/cuts/62x75/cut.jpg',
#    'thumb124x150': '/assets/images/6/8/4/310240684/cuts/124x150/cut.jpg',
#    'photo180x218': '/assets/images/6/8/4/310240684/cuts/180x218/cut.jpg',
#    'photo360x436': '/assets/images/6/8/4/310240684/cuts/360x436/cut.jpg'}]]

# %%
#The 2019 MLB Int Class

mlb_json_id_url = 'http://m.mlb.com/gen/players/prospects/2019/playerProspects.json'
response = requests.get(mlb_json_id_url)
response.status_code
all_json = response.json()
int_prospect_list_2019 = all_json['prospect_players']['int']
int_player_ids_2019 = []
int_player_ranks_2019 = []
int_player_first_name_2019 = []
int_player_last_name_2019 = []
int_player_position_2019 = []
for i in int_prospect_list_2019:
    int_player_id_2019 = str(i['player_id'])
    int_player_ids_2019.append(int_player_id_2019)                      
    int_rank_2019 = i["rank"]
    int_player_ranks_2019.append(int_rank_2019)
    int_first_name_2019 = i["player_first_name"]
    int_player_first_name_2019.append(int_first_name_2019)
    int_last_name_2019 = i["player_last_name"]
    int_player_last_name_2019.append(int_last_name_2019)
    int_position_2019 = i["position"]
    int_player_position_2019.append(int_position_2019)
    int_player_id_data_2019 = {'First Name' : int_player_first_name_2019, 'Last Name' : int_player_last_name_2019, 'Player ID' : int_player_ids_2019, 'Position' : int_player_position_2019, 'Player Rank' : int_player_ranks_2019}

int_player_id_dataframe_2019 = pd.DataFrame(int_player_id_data_2019)
int_prospect_list_2019
# Out:
# [{'prospect_year': '2019',
#   'player_id': 'dominguez_jasson',
#   'player_first_name': 'Jasson',
#   'player_last_name': 'Dominguez',
#   'rank': 1,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'NYY',
#   'thumb': '',
#   'thumb62x75': '/assets/images/7/3/0/306862730/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/7/3/0/306862730/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/7/3/0/306862730/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/7/3/0/306862730/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'puason_robert',
#   'player_first_name': 'Robert',
#   'player_last_name': 'Puason',
#   'rank': 2,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'OAK',
#   'thumb': '',
#   'thumb62x75': '/assets/images/7/5/8/306862758/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/7/5/8/306862758/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/7/5/8/306862758/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/7/5/8/306862758/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'leon_pedro',
#   'player_first_name': 'Pedro',
#   'player_last_name': 'Leon',
#   'rank': 3,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': '',
#   'thumb': '',
#   'thumb62x75': '/assets/images/6/4/8/312705648/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/6/4/8/312705648/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/6/4/8/312705648/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/6/4/8/312705648/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'vera_norge',
#   'player_first_name': 'Norge',
#   'player_last_name': 'Vera',
#   'rank': 4,
#   'position': 'RHP',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': '',
#   'thumb': '',
#   'thumb62x75': '/assets/images/0/1/2/312738012/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/0/1/2/312738012/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/0/1/2/312738012/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/0/1/2/312738012/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'lora_bayron',
#   'player_first_name': 'Bayron',
#   'player_last_name': 'Lora',
#   'rank': 5,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'TEX',
#   'thumb': '',
#   'thumb62x75': '/assets/images/2/9/8/306863298/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/2/9/8/306863298/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/2/9/8/306863298/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/2/9/8/306863298/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'rodriguez_luis',
#   'player_first_name': 'Luis',
#   'player_last_name': 'Rodriguez',
#   'rank': 6,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'LAD',
#   'thumb': '',
#   'thumb62x75': '/assets/images/2/6/8/306991268/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/2/6/8/306991268/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/2/6/8/306991268/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/2/6/8/306991268/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'pena_erick',
#   'player_first_name': 'Erick',
#   'player_last_name': 'Pena',
#   'rank': 7,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'KC',
#   'thumb': '',
#   'thumb62x75': '/assets/images/4/4/8/306916448/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/4/4/8/306916448/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/4/4/8/306916448/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/4/4/8/306916448/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'quintero_ronnier',
#   'player_first_name': 'Ronnier',
#   'player_last_name': 'Quintero',
#   'rank': 8,
#   'position': 'C',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'CHC',
#   'thumb': '',
#   'thumb62x75': '/assets/images/3/9/8/306916398/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/3/9/8/306916398/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/3/9/8/306916398/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/3/9/8/306916398/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'cappe_yiddi',
#   'player_first_name': 'Yiddi',
#   'player_last_name': 'Cappe',
#   'rank': 9,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': '',
#   'thumb': '',
#   'thumb62x75': '/assets/images/6/4/8/306916648/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/6/4/8/306916648/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/6/4/8/306916648/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/6/4/8/306916648/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'rodriguez_emmanuel',
#   'player_first_name': 'Emmanuel',
#   'player_last_name': 'Rodriguez',
#   'rank': 10,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'MIN',
#   'thumb': '',
#   'thumb62x75': '/assets/images/9/3/6/306916936/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/9/3/6/306916936/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/9/3/6/306916936/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/9/3/6/306916936/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'vera_arol',
#   'player_first_name': 'Arol',
#   'player_last_name': 'Vera',
#   'rank': 11,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'LAA',
#   'thumb': '',
#   'thumb62x75': '/assets/images/1/8/8/306917188/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/1/8/8/306917188/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/1/8/8/306917188/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/1/8/8/306917188/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'salas_jose',
#   'player_first_name': 'Jose',
#   'player_last_name': 'Salas',
#   'rank': 12,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'MIA',
#   'thumb': '',
#   'thumb62x75': '/assets/images/0/6/0/306919060/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/0/6/0/306919060/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/0/6/0/306919060/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/0/6/0/306919060/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'made_kevin',
#   'player_first_name': 'Kevin',
#   'player_last_name': 'Made',
#   'rank': 13,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'CHC',
#   'thumb': '',
#   'thumb62x75': '/assets/images/5/7/8/306917578/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/5/7/8/306917578/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/5/7/8/306917578/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/5/7/8/306917578/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'amador_adael',
#   'player_first_name': 'Adael',
#   'player_last_name': 'Amador',
#   'rank': 14,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'COL',
#   'thumb': '',
#   'thumb62x75': '/assets/images/1/7/0/306918170/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/1/7/0/306918170/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/1/7/0/306918170/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/1/7/0/306918170/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'jorge_dyan',
#   'player_first_name': 'Dyan',
#   'player_last_name': 'Jorge',
#   'rank': 15,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': '',
#   'thumb': '',
#   'thumb62x75': '/assets/images/2/7/8/312757278/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/2/7/8/312757278/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/2/7/8/312757278/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/2/7/8/312757278/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'medina_luis',
#   'player_first_name': 'Luis',
#   'player_last_name': 'Medina',
#   'rank': 16,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'MIL',
#   'thumb': '',
#   'thumb62x75': '/assets/images/9/3/4/306918934/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/9/3/4/306918934/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/9/3/4/306918934/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/9/3/4/306918934/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'lorenzo_dauri',
#   'player_first_name': 'Dauri',
#   'player_last_name': 'Lorenzo',
#   'rank': 17,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'HOU',
#   'thumb': '',
#   'thumb62x75': '/assets/images/7/0/6/306918706/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/7/0/6/306918706/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/7/0/6/306918706/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/7/0/6/306918706/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'mena_ismael',
#   'player_first_name': 'Ismael',
#   'player_last_name': 'Mena',
#   'rank': 18,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'SD',
#   'thumb': '',
#   'thumb62x75': '/assets/images/7/5/2/306919752/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/7/5/2/306919752/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/7/5/2/306919752/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/7/5/2/306919752/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'lara_andry',
#   'player_first_name': 'Andry',
#   'player_last_name': 'Lara',
#   'rank': 19,
#   'position': 'RHP',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'WAS',
#   'thumb': '/assets/images/1/7/4/306907174/cuts/74x74/cut.jpg',
#   'thumb62x75': '/assets/images/1/7/4/306907174/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/1/7/4/306907174/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/1/7/4/306907174/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/1/7/4/306907174/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'acosta_maximo',
#   'player_first_name': 'Maximo',
#   'player_last_name': 'Acosta',
#   'rank': 20,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'TEX',
#   'thumb': '',
#   'thumb62x75': '/assets/images/6/5/2/306906652/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/6/5/2/306906652/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/6/5/2/306906652/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/6/5/2/306906652/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'diaz_jhon',
#   'player_first_name': 'Jhon',
#   'player_last_name': 'Diaz',
#   'rank': 21,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'TB',
#   'thumb': '',
#   'thumb62x75': '/assets/images/3/3/8/306946338/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/3/3/8/306946338/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/3/3/8/306946338/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/3/3/8/306946338/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'medina_brayan',
#   'player_first_name': 'Brayan',
#   'player_last_name': 'Medina',
#   'rank': 22,
#   'position': 'RHP',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'SD',
#   'thumb': '/assets/images/3/1/0/306906310/cuts/74x74/cut.jpg',
#   'thumb62x75': '/assets/images/3/1/0/306906310/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/3/1/0/306906310/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/3/1/0/306906310/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/3/1/0/306906310/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'cruz_cristopher',
#   'player_first_name': 'Cristopher',
#   'player_last_name': 'Cruz',
#   'rank': 23,
#   'position': 'RHP',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'PIT',
#   'thumb': '/assets/images/2/8/6/306906286/cuts/74x74/cut.jpg',
#   'thumb62x75': '/assets/images/2/8/6/306906286/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/2/8/6/306906286/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/2/8/6/306906286/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/2/8/6/306906286/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'cardozo_kristian',
#   'player_first_name': 'Kristian',
#   'player_last_name': 'Cardozo',
#   'rank': 24,
#   'position': 'RHP',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'SEA',
#   'thumb': '/assets/images/3/4/2/306865342/cuts/74x74/cut.jpg',
#   'thumb62x75': '/assets/images/3/4/2/306865342/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/3/4/2/306865342/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/3/4/2/306865342/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/3/4/2/306865342/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'preciado_reginald',
#   'player_first_name': 'Reginald',
#   'player_last_name': 'Preciado',
#   'rank': 25,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'SD',
#   'thumb': '',
#   'thumb62x75': '/assets/images/3/0/6/306865306/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/3/0/6/306865306/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/3/0/6/306865306/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/3/0/6/306865306/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'vinicio_esmerlin',
#   'player_first_name': 'Esmerlin',
#   'player_last_name': 'Vinicio',
#   'rank': 26,
#   'position': 'LHP',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'SF',
#   'thumb': '',
#   'thumb62x75': '/assets/images/0/5/8/306865058/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/0/5/8/306865058/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/0/5/8/306865058/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/0/5/8/306865058/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'sanchez_junior',
#   'player_first_name': 'Junior',
#   'player_last_name': 'Sanchez',
#   'rank': 27,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'MIA',
#   'thumb': '/assets/images/8/5/8/306864858/cuts/74x74/cut.jpg',
#   'thumb62x75': '/assets/images/8/5/8/306864858/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/8/5/8/306864858/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/8/5/8/306864858/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/8/5/8/306864858/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'pastrano_jose',
#   'player_first_name': 'Jose',
#   'player_last_name': 'Pastrano',
#   'rank': 28,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'CLE',
#   'thumb': '',
#   'thumb62x75': '/assets/images/2/7/2/306864272/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/2/7/2/306864272/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/2/7/2/306864272/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/2/7/2/306864272/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'ramirez_alexander',
#   'player_first_name': 'Alexander',
#   'player_last_name': 'Ramirez',
#   'rank': 29,
#   'position': 'OF',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'NYM',
#   'thumb': '/assets/images/0/4/8/306864048/cuts/74x74/cut.jpg',
#   'thumb62x75': '/assets/images/0/4/8/306864048/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/0/4/8/306864048/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/0/4/8/306864048/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/0/4/8/306864048/cuts/360x436/cut.jpg'},
#  {'prospect_year': '2019',
#   'player_id': 'de_castro_rikelvin',
#   'player_first_name': 'Rikelvin',
#   'player_last_name': 'De Castro',
#   'rank': 30,
#   'position': 'SS',
#   'preseason100': '',
#   'preseason20': '',
#   'team_file_code': 'TOR',
#   'thumb': '/assets/images/0/1/2/306864012/cuts/74x74/cut.jpg',
#   'thumb62x75': '/assets/images/0/1/2/306864012/cuts/62x75/cut.jpg',
#   'thumb124x150': '/assets/images/0/1/2/306864012/cuts/124x150/cut.jpg',
#   'photo180x218': '/assets/images/0/1/2/306864012/cuts/180x218/cut.jpg',
#   'photo360x436': '/assets/images/0/1/2/306864012/cuts/360x436/cut.jpg'}]

# %%
#The 2019 MLB Team Top 30s

mlb_json_id_url = 'http://m.mlb.com/gen/players/prospects/2019/playerProspects.json'
response = requests.get(mlb_json_id_url)
response.status_code
team_key = ['ana', 'hou', 'oak', 'tor', 'atl', 'mil', 'stl', 'chc', 'ari', 'la', 'sf', 'cle', 'sea', 'mia', 'nym', 'was', 'bal', 'sd', 'phi', 'pit', 'tex', 'tb', 'cin', 'bos', 'col', 'kc', 'det', 'min', 'cws', 'nyy']
all_json = response.json()
team_prospect_list_2019 = []
json_team_code_list = []
for i in team_key:
    team_prospect_list_2019 = all_json['prospect_players'][i]
    json_team_code_list.append(team_prospect_list_2019)
json_team_code_list


team_player_ids_2019 = []
team_player_ranks_2019 = []
team_player_first_name_2019 = []
team_player_last_name_2019 = []
tean_player_position_2019 = []
for i in team_prospect_list_2019:
    team_player_id_2019 = str(i['player_id'])
    team_player_ids_2019.append(int_player_id_2019)                      
    team_rank_2019 = i["rank"]
    team_player_ranks_2019.append(int_rank_2019)
    team_first_name_2019 = i["player_first_name"]
    team_player_first_name_2019.append(int_first_name_2019)
    team_last_name_2019 = i["player_last_name"]
    team_player_last_name_2019.append(int_last_name_2019)
    team_position_2019 = i["position"]
    team_player_position_2019.append(int_position_2019)
    team_player_id_data_2019 = {'First Name' : team_player_first_name_2019, 'Last Name' : team_player_last_name_2019, 'Player ID' : team_player_ids_2019, 'Position' : team_player_position_2019, 'Player Rank' : team_player_ranks_2019}

team_player_id_dataframe_2019 = pd.DataFrame(team_player_id_data_2019)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2019/"
int_prospect_url_list_2019 = []
link_status_2019 = []
#making links
for i in int_player_ids_2019:
    prospect_url = pipeline_url + i + '.json'
    int_prospect_url_list_2019.append(prospect_url)

#testing links
for i in int_prospect_url_list_2019:    
    response = requests.get(i)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2019.append(link)
    
#making initial list of player scout-reports/cards
int_card_list_2019 = []
for i in int_prospect_url_list_2019:    
    response = requests.get(i)
    int_player_card_framed_2019 = response.json()
    int_player_card_2019 = int_player_card_framed_2019['prospect_player']
    int_player_card_2019
    int_player_report_and_video_2019 = int_player_card_2019['content']
    int_player_report_2019 = int_player_report_and_video_2019['default']
    int_card_list_2019.append(int_player_report_2019)



int_report_trim_1_list_2019 = []
for i in int_card_list_2019:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    int_report_trim_1_list_2019.append(report_trim_1)

int_report_cleaner_list_2019 = []
for i in int_report_trim_1_list_2019:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    int_report_cleaner_list_2019.append(trim_a)

int_reports_2019 = []
for i in int_report_cleaner_list_2019:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    lowered = without_n.lower()
    int_reports_2019.append(lowered)

int_player_id_dataframe_2019['Written Report'] = int_reports_2019
int_top_one_hundred_data_2019 = int_player_id_dataframe_2019


full_int_2019 = []

for i in int_reports_2019:
    
    int_text_2019 = TextBlob(i)
   
    int_score_2019 = int_text_2019.sentiment
    
    full_int_2019.append(int_score_2019)


int_top_one_hundred_data_2019['Sentiment Score'] = full_int_2019

sorted_int_2019 = int_top_one_hundred_data_2019.sort_values(by=['Sentiment Score'],ascending = False)
sorted_int_2019 = sorted_int_2019.drop(['Written Report', 'Player ID'], axis = 1)
sorted_int_2019

# %%
#The 2019 MLB Int Class

mlb_json_id_url = 'http://m.mlb.com/gen/players/prospects/2019/playerProspects.json'
response = requests.get(mlb_json_id_url)
response.status_code
all_json = response.json()
int_prospect_list_2019 = all_json['prospect_players']['int']
int_player_ids_2019 = []
int_player_ranks_2019 = []
int_player_first_name_2019 = []
int_player_last_name_2019 = []
int_player_position_2019 = []
for i in int_prospect_list_2019:
    int_player_id_2019 = str(i['player_id'])
    int_player_ids_2019.append(int_player_id_2019)                      
    int_rank_2019 = i["rank"]
    int_player_ranks_2019.append(int_rank_2019)
    int_first_name_2019 = i["player_first_name"]
    int_player_first_name_2019.append(int_first_name_2019)
    int_last_name_2019 = i["player_last_name"]
    int_player_last_name_2019.append(int_last_name_2019)
    int_position_2019 = i["position"]
    int_player_position_2019.append(int_position_2019)
    int_player_id_data_2019 = {'First Name' : int_player_first_name_2019, 'Last Name' : int_player_last_name_2019, 'Player ID' : int_player_ids_2019, 'Position' : int_player_position_2019, 'Player Rank' : int_player_ranks_2019}

int_player_id_dataframe_2019 = pd.DataFrame(int_player_id_data_2019)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2019/"
int_prospect_url_list_2019 = []
link_status_2019 = []
#making links
for i in int_player_ids_2019:
    prospect_url = pipeline_url + i + '.json'
    int_prospect_url_list_2019.append(prospect_url)

#testing links
for i in int_prospect_url_list_2019:    
    response = requests.get(i)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2019.append(link)
    
#making initial list of player scout-reports/cards
int_card_list_2019 = []
for i in int_prospect_url_list_2019:    
    response = requests.get(i)
    int_player_card_framed_2019 = response.json()
    int_player_card_2019 = int_player_card_framed_2019['prospect_player']
    int_player_card_2019
    int_player_report_and_video_2019 = int_player_card_2019['content']
    int_player_report_2019 = int_player_report_and_video_2019['default']
    int_card_list_2019.append(int_player_report_2019)



int_report_trim_1_list_2019 = []
for i in int_card_list_2019:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    int_report_trim_1_list_2019.append(report_trim_1)

int_report_cleaner_list_2019 = []
for i in int_report_trim_1_list_2019:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    int_report_cleaner_list_2019.append(trim_a)

int_reports_2019 = []
for i in int_report_cleaner_list_2019:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    lowered = without_n.lower()
    int_reports_2019.append(lowered)

int_player_id_dataframe_2019['Written Report'] = int_reports_2019
int_top_one_hundred_data_2019 = int_player_id_dataframe_2019


full_int_2019 = []

for i in int_reports_2019:
    
    int_text_2019 = TextBlob(i)
   
    int_score_2019 = int_text_2019.sentiment
    
    full_int_2019.append(int_score_2019)


int_top_one_hundred_data_2019['Sentiment Score'] = full_int_2019

sorted_int_2019 = int_top_one_hundred_data_2019.sort_values(by=['Sentiment Score'],ascending = False)
sorted_int_2019 = sorted_int_2019.drop(['Written Report', 'Player ID'], axis = 1)
sorted_int_2019
