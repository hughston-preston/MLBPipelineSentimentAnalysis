# %%
###Draft

###Part 1: scraping initial 2019 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url = 'http://m.mlb.com/gen/players/prospects/2020/playerProspects.json'
response = requests.get(mlb_json_id_url)
response.status_code
all_json = response.json()
draft_prospect_list = all_json['prospect_players']['draft']
draft_player_ids = []
draft_player_ranks = []
draft_player_first_name = []
draft_player_last_name = []
draft_player_position = []
for i in draft_prospect_list:
    player_id = str(i['player_id'])
    draft_player_ids.append(player_id)                      
    rank = i["rank"]
    draft_player_ranks.append(rank)
    first_name = i["player_first_name"]
    draft_player_first_name.append(first_name)
    last_name = i["player_last_name"]
    draft_player_last_name.append(last_name)
    position = i["position"]
    draft_player_position.append(position)
    player_id_data = {'First Name' : draft_player_first_name, 'Last Name' : draft_player_last_name, 'Player ID' : draft_player_ids, 'Position' : draft_player_position, 'Player Rank' : draft_player_ranks}

draft_player_id_dataframe = pd.DataFrame(player_id_data)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2020/"
draft_prospect_url_list = []
report_list = []
draft_link_status = []
#testing links
for i in draft_player_ids:
    prospect_url = pipeline_url + i + '.json'
    draft_prospect_url_list.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    draft_link_status.append(link)
    
#making initial list of player scout-reports/cards
draft_card_list = []
for i in draft_prospect_url_list:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    draft_card_list.append(player_report)



draft_report_trim_1_list = []
for i in draft_card_list:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    draft_report_trim_1_list.append(report_trim_1)

draft_report_cleaner_list = []
for i in draft_report_trim_1_list:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    draft_report_cleaner_list.append(trim_a)

draft_reports = []
for i in draft_report_cleaner_list:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    lowered = without_n.lower()
    draft_reports.append(lowered)

draft_player_id_dataframe['Written Report'] = draft_reports
draft_top_one_hundred_data_2020 = draft_player_id_dataframe

draft_top_one_hundred_data_2020
# Out:
#    First Name       Last Name            Player ID Position  Player Rank  \
# 0     Emerson         Hancock      hancock_emerson      RHP            1
# 1     Spencer       Torkelson    torkelson_spencer       1B            2
# 2      Austin          Martin        martin_austin       SS            3
# 3        Nick        Gonzales        gonzales_nick       2B            4
# 4         Asa            Lacy             lacy_asa      LHP            5
# 5     Garrett        Mitchell     mitchell_garrett       OF            6
# 6       Jared          Kelley         kelley_jared      RHP            7
# 7        Mick            Abel            abel_mick      RHP            8
# 8        Nick          Bitsko          bitsko_nick      RHP            9
# 9     Garrett         Crochet      crochet_garrett      LHP           10
# 10     Austin        Hendrick      hendrick_austin       OF           11
# 11         Ed          Howard            howard_ed       SS           12
# 12     Heston        Kjerstad      kjerstad_heston       OF           13
# 13       Reid         Detmers         detmers_reid      LHP           14
# 14      Casey          Martin         martin_casey       SS           15
# 15         JT            Ginn              ginn_jt      RHP           16
# 16     Robert         Hassell       hassell_robert       OF           17
# 17      Tyler      Soderstrom     soderstrom_tyler        C           18
# 18     Carmen      Mlodzinski    mlodzinski_carmen      RHP           19
# 19         CJ         Van Eyk           van_eyk_cj      RHP           20
# 20     Jordan          Walker        walker_jordan       3B           21
# 21    Patrick          Bailey       bailey_patrick        C           22
# 22        Zac            Veen             veen_zac       OF           23
# 23     Austin           Wells         wells_austin        C           24
# 24        Max           Meyer            meyer_max      RHP           25
# 25       Pete  Crow-Armstrong  crow_armstrong_pete       OF           26
# 26       Drew            Romo            romo_drew        C           27
# 27       Cole          Wilcox          wilcox_cole      RHP           28
# 28       Cade         Cavalli         cavalli_cade      RHP           29
# 29     Tanner           Burns         burns_tanner      RHP           30
# ..        ...             ...                  ...      ...          ...
# 70     Isaiah          Greene        greene_isaiah       OF           71
# 71       Burl        Carraway        carraway_burl      LHP           72
# 72      Jason        Savacool       savacool_jason      RHP           73
# 73       Kyle        Harrison        harrison_kyle      LHP           74
# 74        Ben       Hernandez        hernandez_ben      RHP           75
# 75      Casey         Schmitt        schmitt_casey   3B/RHP           76
# 76       Kyle            Teel            teel_kyle        C           77
# 77      Kevin            Abel           abel_kevin      RHP           78
# 78    Enrique       Bradfield    bradfield_enrique       OF           79
# 79     Cayden         Wallace       wallace_cayden       3B           80
# 80     Hudson          Haskin        haskin_hudson       OF           81
# 81     Carter         Baumler       baumler_carter      RHP           82
# 82      Milan       Tolentino      tolentino_milan       SS           83
# 83      Nolan          McLean         mclean_nolan      RHP           84
# 84     Connor        Phillips      phillips_connor      RHP           85
# 85       Zach       McCambley       mccambley_zach      RHP           86
# 86  Markevian           Hence      hence_markevian      RHP           87
# 87     Daniel           Susac         susac_daniel        C           88
# 88      David       Calabrese      calabrese_david       OF           89
# 89      Timmy         Manning        manning_timmy      LHP           90
# 90     Colten           Keith         keith_colten   RHP/3B           91
# 91       Jack        Leftwich        leftwich_jack      RHP           92
# 92       Kyle            Hurt            hurt_kyle      RHP           93
# 93     Andrew          Abbott        abbott_andrew      LHP           94
# 94       Kyle         Nicolas         nicolas_kyle      RHP           95
# 95     Carson         Seymour       seymour_carson      RHP           96
# 96         RJ        Dabovich          dabovich_rj      RHP           97
# 97       Ryan           Bruno           bruno_ryan      LHP           98
# 98    Jackson          Miller       miller_jackson        C           99
# 99         AJ        Vukovich          vukovich_aj       3B          100
#
#                                        Written Report
# 0   hancock rated as georgia's second-best prep pi...
# 1   torkelson wasn't drafted as a high schooler fr...
# 2   martin has a chance to follow the path set by ...
# 3   gonzales has hit wherever he's been, but there...
# 4   though lacy exuded projection and top-five-rou...
# 5   mitchell was a solid high school prospect at o...
# 6   refugio (texas) high never has produced a draf...
# 7   a high school player from the state of oregon ...
# 8   the scouting industry had seen a good amount o...
# 9   crochet rated as mississippi's best prep pitch...
# 10  see hendrick, the pittsburgh-area high school ...
# 11  the starting shortstop on the jackie robinson ...
# 12  a 36th-round pick by the mariners as a texas h...
# 13  one of illinois' best high school pitching pro...
# 14  scouts rated martin as the best high school pr...
# 15  the dodgers selected ginn 30th overall out of ...
# 16  hassell's offseason started and ended well, as...
# 17  back in 1993, steve soderstrom was the no. 6 o...
# 18  the palmetto state's top prep prospect in 2017...
# 19  a high school pitcher in florida who was on th...
# 20  arguably the best duke baseball recruit ever, ...
# 21  coming out of a wesleyan christian academy (hi...
# 22   there have been high school outfielders in th...
# 23  wells was a solid prospect at las vegas high s...
# 24  meyer starred at woodbury (minn.) high but lac...
# 25  hailing from the same high school, harvard-wes...
# 26  the track record of high school catchers in th...
# 27  not only does georgia have a candidate for the...
# 28  cavalli didn't take the mound until he was a s...
# 29  burns displayed first-round stuff when he was ...
# ..                                                ...
# 70  after a lackluster junior season at corona hig...
# 71  carraway first piqued dallas baptist's interes...
# 72  baldwinsville, new york's baker high school, l...
# 73  de la salle high school in northern california...
# 74  the best pitcher in the inaugural prospect dev...
# 75  two-way players have been a hot trend at the m...
# 76  new jersey has seen three players get drafted ...
# 77  abel was a solid high school prospect in the s...
# 78  bradfield entered the summer showcase circuit ...
# 79  arkansas has locked down all of the top in-sta...
# 80  avon (conn.) old farms school produced an athl...
# 81  baumler boosted his stock late in the showcase...
# 82  in 1983, jose tolentino helped the university ...
# 83  though mclean shows intriguing potential on th...
# 84  texas junior colleges could produce several ea...
# 85  coastal carolina has produced just three top-t...
# 86  the state of arkansas has had just three high ...
# 87  jesuit high school in sacramento has a well-de...
# 88  there has been a player from ontario taken in ...
# 89  there are high school arms who are all about a...
# 90  gatorade's mississippi high school player of t...
# 91  leftwich moved from his high school to focus o...
# 92  ming out of torrey pines high school in san di...
# 93  once upon a time, college relievers were highl...
# 94  as a jackson (ohio) high senior in 2016-17, ni...
# 95  kansas state has produced just one top-100 pic...
# 96  dabovich might have been a decent draft prospe...
# 97  projectable high school pitchers show up in ev...
# 98  while left-handed-hitting catchers are always ...
# 99  the state of wisconsin has produced several re...
#
# [100 rows x 6 columns]

# %%
###2019

###Part 1: scraping initial 2019 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url_2019 = 'http://m.mlb.com/gen/players/prospects/2019/playerProspects.json'
response_2019 = requests.get(mlb_json_id_url_2019)
response_2019.status_code
all_json_2019 = response_2019.json()
prospect_list_2019 = all_json_2019['prospect_players']['prospects']
player_ids_2019 = []
player_ranks_2019 = []
player_first_name_2019 = []
player_last_name_2019 = []
player_position_2019 = []
player_team_2019 = []
for i in prospect_list_2019:
    player_id = str(i['player_id'])
    player_ids_2019.append(player_id)                      
    rank = i["rank"]
    player_ranks_2019.append(rank)
    first_name = i["player_first_name"]
    player_first_name_2019.append(first_name)
    last_name = i["player_last_name"]
    player_last_name_2019.append(last_name)
    position = i["position"]
    player_position_2019.append(position)
    team = i["team_file_code"]
    player_team_2019.append(team)
    player_id_data_2019 = {'First Name' : player_first_name_2019, 'Last Name' : player_last_name_2019, 'Player ID' : player_ids_2019, 'Team' : player_team_2019, 'Position' : player_position_2019, 'Player Rank' : player_ranks_2019}


player_id_dataframe_2019 = pd.DataFrame(player_id_data_2019)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2019/"
prospect_url_list_2019 = []
link_status_2019 = []
#testing links
for i in player_ids_2019:
    prospect_url = pipeline_url + i + '.json'
    prospect_url_list_2019.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2019.append(link)
    
#making initial list of player scout-reports/cards
card_list_2019 = []
for i in prospect_url_list_2019:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    card_list_2019.append(player_report)



report_trim_1_list_2019 = []
for i in card_list_2019:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    report_trim_1_list_2019.append(report_trim_1)

report_cleaner_list_2019 = []
for i in report_trim_1_list_2019:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    report_cleaner_list_2019.append(trim_a)

reports_2019 = []
for i in report_cleaner_list_2019:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    lowered = without_n.lower()
    reports_2019.append(lowered)

player_id_dataframe_2019['Written Report'] = reports_2019
top_one_hundred_data_2019 = player_id_dataframe_2019
top_one_hundred_data_2019
# Out:
#    First Name  Last Name Player ID Team Position  Player Rank  \
# 0      Wander     Franco    677551   TB       SS            1
# 1       Gavin        Lux    666158   LA    SS/2B            2
# 2        Luis     Robert    673357  CWS       OF            3
# 3   MacKenzie       Gore    669022   SD      LHP            4
# 4          Jo      Adell    666176  ANA       OF            5
# 5       Adley  Rutschman    668939  BAL        C            6
# 6       Casey       Mize    663554  DET      RHP            7
# 7       Bobby   Witt Jr.    677951   KC       SS            8
# 8       Royce      Lewis    668904  MIN       SS            9
# 9        Nate    Pearson    663878  TOR      RHP           10
# 10   Cristian      Pache    665506  ATL       OF           11
# 11    Brendan      McKay    656713   TB   LHP/DH           12
# 12     Jarred    Kelenic    672284  SEA       OF           13
# 13    Brendan    Rodgers    663898  COL      INF           14
# 14       Alex  Kirilloff    666135  MIN    OF/1B           15
# 15    Forrest    Whitley    666215  HOU      RHP           16
# 16    Michael     Kopech    656629  CWS      RHP           17
# 17      Jesus    Luzardo    666200  OAK      LHP           18
# 18       Joey       Bart    663698   SF        C           19
# 19     Carter    Kieboom    666198  WAS    SS/2B           20
# 20     Andrew     Vaughn    683734  CWS       1B           21
# 21      Sixto    Sanchez    664350  MIA      RHP           22
# 22       Drew     Waters    671221  ATL       OF           23
# 23      Dylan    Carlson    666185  STL       OF           24
# 24      Julio  Rodriguez    677594  SEA       OF           25
# 25      Mitch     Keller    656605  PIT      RHP           26
# 26       Matt    Manning    666159  DET      RHP           27
# 27     Taylor   Trammell    666211   SD       OF           28
# 28         JJ     Bleday    668709  MIA       OF           29
# 29       Luis     Patino    672715   SD      RHP           30
# ..        ...        ...       ...  ...      ...          ...
# 70   Kristian   Robinson    677565  ARI       OF           71
# 71     Xavier    Edwards    669364   TB    2B/SS           72
# 72        Sam       Huff    669087  TEX        C           73
# 73      Tarik     Skubal    669373  DET      LHP           74
# 74     Josiah       Gray    680686   LA      RHP           75
# 75     Jordan  Balazovic    666364  MIN      RHP           76
# 76     Trevor    Larnach    663616  MIN       OF           77
# 77       Hans     Crouse    668968  TEX      RHP           78
# 78    Triston   McKenzie    663474  CLE      RHP           79
# 79      Ronny   Mauricio    677595  NYM       SS           80
# 80      Brett       Baty    683146  NYM       3B           81
# 81    Estevan    Florial    664314  NYY       OF           82
# 82      Monte   Harrison    656509  MIA       OF           83
# 83       Ryan    Rolison    669020  COL      LHP           84
# 84    Triston      Casas    671213  BOS    1B/3B           85
# 85       Luis  Campusano    669134   SD        C           86
# 86      Jeter      Downs    669023  BOS       SS           87
# 87    Spencer     Howard    675921  PHI      RHP           88
# 88     Bryson      Stott    681082  PHI       SS           89
# 89     Miguel      Amaya    665804  CHC        C           90
# 90       Luis     Garcia    671277  WAS      INF           91
# 91     Andres    Gimenez    665926  NYM       SS           92
# 92   Jonathan      India    663697  CIN       3B           93
# 93      Shane        Baz    669358   TB      RHP           94
# 94     Corbin    Carroll    682998  ARI       OF           95
# 95       Seth       Beer    666179  ARI    1B/OF           96
# 96      Tyler    Freeman    671289  CLE       SS           97
# 97      Brice     Turang    668930  MIL    SS/2B           98
# 98     Edward    Cabrera    665795  MIA      RHP           99
# 99    Daulton     Varsho    662139  ARI        C          100
#
#                                        Written Report
# 0   a switch-hitting shortstop with deep baseball ...
# 1   lux developed fine baseball instincts growing ...
# 2   shortly before new rules severely curtailed in...
# 3   as a whiteville (n.c.) hs junior, gore went 12...
# 4   remember when there was concern about adell's ...
# 5   sometimes a player who enters his draft season...
# 6   undrafted out of high school, mize honored his...
# 7   bobby witt went third overall in the 1985 draf...
# 8   while it surprised some when the twins took le...
# 9   pearson had some late helium ahead of the 2017...
# 10  ever since pache signed back in july 2015, whe...
# 11  the recipient of the john olerud two-way playe...
# 12  kelenic was one of the top high school hitters...
# 13  when rodgers was coming out of the florida hig...
# 14  kirilloff was one of the better pure hitters i...
# 15  the astros rated whitley as the best high scho...
# 16  kopech signed with the red sox for $1.5 millio...
# 17  when the a's got luzardo from the nationals as...
# 18  bart turned down the chance to go in the first...
# 19  the nationals selected kieboom with the first ...
# 20  vaughn went from an unheralded northern califo...
# 21  sanchez may have been an under-the-radar signi...
# 22  the braves deservedly have a reputation for de...
# 23  hailing from the elk grove high school program...
# 24  rodriguez was in the top 10 of mlb pipeline's ...
# 25  hailing from the iowa high school ranks, kelle...
# 26  the tigers knew that manning might be a bit of...
# 27  when the reds signed nick senzel as the no. 2 ...
# 28  bleday won a starting job at vanderbilt as a f...
# 29  patino may not have come with the type of fanf...
# ..                                                ...
# 70  two years removed from their signing of shorts...
# 71  edwards passed on a vanderbilt commitment to s...
# 72  huff topped arizona high schoolers with 14 hom...
# 73  tommy john surgery wiped out much of skubal's ...
# 74  los angeles cleared roster spots and salary wh...
# 75  as the 2016 draft approached, balazovic travel...
# 76  college hitters who perform as juniors, partic...
# 77  few pitchers in the 2017 high school class cou...
# 78  perhaps the most projectable pitcher in the 20...
# 79  the mets were aggressive in the 2017 internati...
# 80  as a 19-year-old high school senior, baty was ...
# 81  assuming the identity of haniel de oleo when r...
# 82  a three-sport standout in high school, harriso...
# 83  after taking rolison as a draft-eligible sopho...
# 84  though the red sox picked 26th in the 2018 dra...
# 85  with potential on both offense and defense, ca...
# 86  named after derek jeter and the younger brothe...
# 87  a reliever in his first year at cal poly, howa...
# 88  college shortstops with solid all-around tools...
# 89  chicago invested heavily in the international ...
# 90  there's something to be said about players wit...
# 91  the mets have never shied away from pushing yo...
# 92  after a pair of relatively ordinary years at f...
# 93  baz was a two-way standout at concordia luther...
# 94  from a physical standpoint, carroll, with his ...
# 95  beer graduated from high school a semester ear...
# 96  one of the top high school hitters in southern...
# 97  the brewers didn't expect turang to still be o...
# 98  signed for $100,000 out of the dominican repub...
# 99  the son of former big leaguer gary varsho and ...
#
# [100 rows x 7 columns]

# %%
###2018

###Part 1: scraping initial 2019 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url_2018 = 'http://m.mlb.com/gen/players/prospects/2018/playerProspects.json'
response_2018 = requests.get(mlb_json_id_url_2018)
response_2018.status_code
all_json_2018 = response_2018.json()
prospect_list_2018 = all_json_2018['prospect_players']['prospects']
player_ids_2018 = []
player_ranks_2018 = []
player_first_name_2018 = []
player_last_name_2018 = []
player_position_2018 = []
player_team_2018 = []
for i in prospect_list_2018:
    player_id = str(i['player_id'])
    player_ids_2018.append(player_id)                      
    rank = i["rank"]
    player_ranks_2018.append(rank)
    first_name = i["player_first_name"]
    player_first_name_2018.append(first_name)
    last_name = i["player_last_name"]
    player_last_name_2018.append(last_name)
    position = i["position"]
    player_position_2018.append(position)
    team = i["team_file_code"]
    player_team_2018.append(team)
    player_id_data_2018 = {'First Name' : player_first_name_2018, 'Last Name' : player_last_name_2018, 'Player ID' : player_ids_2018, 'Team' : player_team_2018, 'Position' : player_position_2018, 'Player Rank' : player_ranks_2018}


player_id_dataframe_2018 = pd.DataFrame(player_id_data_2018)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2018/"
prospect_url_list_2018 = []
link_status_2018 = []
#testing links
for i in player_ids_2018:
    prospect_url = pipeline_url + i + '.json'
    prospect_url_list_2018.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2018.append(link)
    
#making initial list of player scout-reports/cards
card_list_2018 = []
for i in prospect_url_list_2018:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    card_list_2018.append(player_report)



report_trim_1_list_2018 = []
for i in card_list_2018:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    report_trim_1_list_2018.append(report_trim_1)

report_cleaner_list_2018 = []
for i in report_trim_1_list_2018:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    report_cleaner_list_2018.append(trim_a)

reports_2018 = []
for i in report_cleaner_list_2018:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    lowered = without_n.lower()
    reports_2018.append(lowered)

player_id_dataframe_2018['Written Report'] = reports_2018
top_one_hundred_data_2018 = player_id_dataframe_2018

top_one_hundred_data_2018
# Out:
#    First Name     Last Name Player ID Team Position  Player Rank  \
# 0    Vladimir  Guerrero Jr.    665489  TOR       3B            1
# 1    Fernando     Tatis Jr.    665487   SD       SS            2
# 2        Eloy       Jimenez    650391  CWS       OF            3
# 3      Victor        Robles    645302  WAS       OF            4
# 4        Kyle        Tucker    663656  HOU       OF            5
# 5        Nick        Senzel    669222  CIN    3B/2B            6
# 6       Royce         Lewis    668904  MIN       SS            7
# 7     Forrest       Whitley    666215  HOU      RHP            8
# 8     Brendan       Rodgers    663898  COL      INF            9
# 9        Alex     Kirilloff    666135  MIN       OF           10
# 10         Bo      Bichette    666182  TOR    SS/2B           11
# 11      Jesus       Luzardo    666200  OAK      LHP           12
# 12  MacKenzie          Gore    669022   SD      LHP           13
# 13     Wander        Franco    677551   TB       SS           14
# 14         Jo         Adell    666176  ANA       OF           15
# 15      Mitch        Keller    656605  PIT      RHP           16
# 16     Taylor      Trammell    666211  CIN       OF           17
# 17      Casey          Mize    663554  DET      RHP           18
# 18    Michael        Kopech    656629  CWS      RHP           19
# 19       Mike        Soroka    647336  ATL      RHP           20
# 20      Sixto       Sanchez    664350  PHI      RHP           21
# 21     Hunter        Greene    668881  CIN      RHP           22
# 22       Joey          Bart    663698   SF        C           23
# 23    Brendan         McKay    656713   TB   LHP/1B           24
# 24      Dylan         Cease    656302  CWS      RHP           25
# 25  Francisco         Mejia    642336   SD     C/OF           26
# 26       Luis         Urias    649966   SD    2B/SS           27
# 27      Brent     Honeywell    641703   TB      RHP           28
# 28       Kyle        Wright    657140  ATL      RHP           29
# 29     Keston         Hiura    669374  MIL       2B           30
# ..        ...           ...       ...  ...      ...          ...
# 70     Dustin           May    669160   LA      RHP           71
# 71    Griffin       Canning    656288  ANA      RHP           72
# 72      Nolan        Gorman    669357  STL       3B           73
# 73     Heliot         Ramos    671218   SF       OF           74
# 74     Travis     Swaggerty    680552  PIT       OF           75
# 75      Logan         Allen    663531   SD      LHP           76
# 76      Blake    Rutherford    666164  CWS       OF           77
# 77       Luiz        Gohara    627894  ATL      LHP           78
# 78       Alex         Faedo    656412  DET      RHP           79
# 79        Jon    Duplantier    641541  ARI      RHP           80
# 80       Luis        Garcia    671277  WAS    SS/3B           81
# 81      Gavin           Lux    666158   LA    SS/2B           82
# 82       Luis        Patino    672715   SD      RHP           83
# 83      Nolan         Jones    666134  CLE       3B           84
# 84     Albert         Abreu    656061  NYY      RHP           85
# 85       Beau       Burrows    663366  DET      RHP           86
# 86     Miguel         Amaya    665804  CHC        C           87
# 87       Cole          Winn    668390  TEX      RHP           88
# 88     Justin          Dunn    643290  SEA      RHP           89
# 89       Nate       Pearson    663878  TOR      RHP           90
# 90       Drew        Waters    671221  ATL       OF           91
# 91       Ryan      Weathers    677960   SD      LHP           92
# 92     Dakota        Hudson    641712  STL      RHP           93
# 93     Colton        Welker    666213  COL       3B           94
# 94       Josh         James    657624  HOU      RHP           95
# 95      Bryse        Wilson    669060  ATL      RHP           96
# 96     Taylor       Widener    642203  ARI      RHP           97
# 97    Brandon         Marsh    669016  ANA       OF           98
# 98      Peter       Lambert    663567  COL      RHP           99
# 99      Kolby        Allard    663465  ATL      LHP          100
#
#                                        Written Report
# 0   the son of 2004 al mvp and nine-time all-star ...
# 1   the son of former 11-year major leaguer fernan...
# 2   the top-rated international prospect during th...
# 3   signed for $225,000 out of the dominican repub...
# 4   the younger brother of former astros outfielde...
# 5   senzel was billed as the top pure hitter in th...
# 6   though ranked as the top high school position ...
# 7   the astros rated whitley higher than any high ...
# 8   mlb pipeline's no. 1-rated prospect in the 201...
# 9   after the twins took kirilloff from the pittsb...
# 10  yet another talented blue jays prospect with d...
# 11  luzardo was already highly regarded by scouts ...
# 12  gore posted gaudy numbers as a whiteville (n.c...
# 13  ranked as mlbpipeline.com's no. 2 prospect for...
# 14  from a raw tools perspective, there may not ha...
# 15  a jump in velocity heading into his senior yea...
# 16  trammell was a talented multi-sport athlete fr...
# 17  mize was too raw to get drafted out of the ala...
# 18  in the four-prospect package obtained from the...
# 19  the braves are not afraid to push young pitche...
# 20  sanchez signed for just $35,000 and immediatel...
# 21  a two-way talent who would have been a first-r...
# 22  a potential top-five-rounds pick after leading...
# 23  regarded as the best two-way draft prospect si...
# 24  cease might have been a first-rounder as a geo...
# 25  originally signed out of the dominican republi...
# 26  signed out of the mexican league in december 2...
# 27  little was known about honeywell when the rays...
# 28  the vanderbilt ace was in the conversation to ...
# 29  the brewers landed arguably the top college hi...
# ..                                                ...
# 70  may boosted his 2016 draft stock by recording ...
# 71  canning looked like a sure-fire first-round pi...
# 72  there may not be another player, prep or colle...
# 73  ramos starred on the high school showcase circ...
# 74  south alabama had never had a first-round pick...
# 75  allen pitched for img academy's (fla.) high sc...
# 76  rutherford began 2016 as the top-rated high sc...
# 77  during his time with the mariners after signin...
# 78  faedo's spot atop 2017 draft boards was initia...
# 79  a shoulder injury that kept him out for his en...
# 80  garcia's baseball bloodlines run deep, as his ...
# 81  the nephew of augie schmidt, the no. 2 overall...
# 82  patino looks like yet another promising prospe...
# 83  one of the premier prep hitters in the 2016 dr...
# 84  gary sanchez's development made brian mccann r...
# 85  the first of two consecutive high school arms ...
# 86  the cubs handed out seven-figure deals to eigh...
# 87  gatorade's colorado player of the year as a ju...
# 88  dunn spent most of his time at boston college ...
# 89  after appearing in 19 games but making only on...
# 90  when waters emerged as one of the best high sc...
# 91  the son former major league pitcher david weat...
# 92  when hudson inexplicably fell to the bottom of...
# 93  part of a stoneman douglas high (parkland, fla...
# 94  james pitched just four innings as a freshman ...
# 95  the braves went all in on high school pitching...
# 96  a 12th-round pick from south carolina who sign...
# 97  marsh is a product of a strong high school pro...
# 98  though lambert had a track record of success a...
# 99  the first of two braves' first-round picks in ...
#
# [100 rows x 7 columns]

# %%
###2017

###Part 1: scraping initial 2019 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url_2017 = 'http://m.mlb.com/gen/players/prospects/2017/playerProspects.json'
response_2017 = requests.get(mlb_json_id_url_2017)
response_2017.status_code
all_json_2017 = response_2017.json()
prospect_list_2017 = all_json_2017['prospect_players']['prospects']
player_ids_2017 = []
player_ranks_2017 = []
player_first_name_2017 = []
player_last_name_2017 = []
player_position_2017 = []
player_team_2017 = []
for i in prospect_list_2017:
    player_id = str(i['player_id'])
    player_ids_2017.append(player_id)                      
    rank = i["rank"]
    player_ranks_2017.append(rank)
    first_name = i["player_first_name"]
    player_first_name_2017.append(first_name)
    last_name = i["player_last_name"]
    player_last_name_2017.append(last_name)
    position = i["position"]
    player_position_2017.append(position)
    team = i["team_file_code"]
    player_team_2017.append(team)
    player_id_data_2017 = {'First Name' : player_first_name_2017, 'Last Name' : player_last_name_2017, 'Player ID' : player_ids_2017, 'Team' : player_team_2017, 'Position' : player_position_2017, 'Player Rank' : player_ranks_2017}


player_id_dataframe_2017 = pd.DataFrame(player_id_data_2017)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2017/"
prospect_url_list_2017 = []
link_status_2017 = []
#testing links
for i in player_ids_2017:
    prospect_url = pipeline_url + i + '.json'
    prospect_url_list_2017.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2017.append(link)
    
#making initial list of player scout-reports/cards
card_list_2017 = []
for i in prospect_url_list_2017:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    card_list_2017.append(player_report)



report_trim_1_list_2017 = []
for i in card_list_2017:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    report_trim_1_list_2017.append(report_trim_1)

report_cleaner_list_2017 = []
for i in report_trim_1_list_2017:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    report_cleaner_list_2017.append(trim_a)

reports_2017 = []
for i in report_cleaner_list_2017:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    lowered = without_n.lower()
    reports_2017.append(lowered)

player_id_dataframe_2017['Written Report'] = reports_2017
top_one_hundred_data_2017 = player_id_dataframe_2017

top_one_hundred_data_2017
# Out:
#    First Name     Last Name Player ID Team Position  Player Rank  \
# 0      Shohei        Ohtani    660271  ANA   RHP/OF            1
# 1     Gleyber        Torres    650402  NYY      INF            2
# 2      Victor        Robles    645302  WAS       OF            3
# 3    Vladimir  Guerrero Jr.    665489  TOR       3B            4
# 4        Eloy       Jimenez    650391  CWS       OF            5
# 5      Ronald         Acuna    660670  ATL       OF            6
# 6     Brendan       Rodgers    663898  COL    SS/2B            7
# 7        Kyle        Tucker    663656  HOU       OF            8
# 8        Nick        Senzel    669222  CIN       3B            9
# 9     Michael        Kopech    656629  CWS      RHP           10
# 10     Walker       Buehler    621111   LA      RHP           11
# 11      Brent     Honeywell    641703   TB      RHP           12
# 12      Lewis       Brinson    621446  MIA       OF           13
# 13  Francisco         Mejia    642336  CLE        C           14
# 14       Alex         Reyes    621052  STL      RHP           15
# 15      Willy        Adames    642715   TB       SS           16
# 16     Austin       Meadows    640457  PIT       OF           17
# 17     Hunter        Greene    668881  CIN      RHP           18
# 18      Mitch        Keller    656605  PIT      RHP           19
# 19    Brendan         McKay    656713   TB   1B/LHP           20
# 20    Triston      McKenzie    663474  CLE      RHP           21
# 21      Kolby        Allard    663465  ATL      LHP           22
# 22       Luis        Robert    673357  CWS       OF           23
# 23       Alex       Verdugo    657077   LA       OF           24
# 24  MacKenzie          Gore    669022   SD      LHP           25
# 25         Bo      Bichette    666182  TOR    SS/2B           26
# 26      Royce         Lewis    668904  MIN       SS           27
# 27      Leody       Taveras    665750  TEX       OF           28
# 28     Mickey        Moniak    666160  PHI       OF           29
# 29       Nick        Gordon    624503  MIN    SS/2B           30
# ..        ...           ...       ...  ...      ...          ...
# 70   Fernando        Romero    622864  MIN      RHP           71
# 71   Anderson      Espinoza    659262   SD      RHP           72
# 72       Jake        Bauers    641343   TB    OF/1B           73
# 73      Jeren       Kendall    656607   LA       OF           74
# 74       J.B.     Bukauskas    656266  HOU      RHP           75
# 75      Shane           Baz    669358  PIT      RHP           76
# 76    Yusniel          Diaz    666783   LA       OF           77
# 77      Tyler         Mahle    641816  CIN      RHP           78
# 78    Estevan       Florial    664314  NYY       OF           79
# 79     Justus     Sheffield    656954  NYY      LHP           80
# 80    Brandon      Woodruff    605540  MIL      RHP           81
# 81     Keston         Hiura    669374  MIL       2B           82
# 82       Luiz        Gohara    627894  ATL      LHP           83
# 83       Jose       De Leon    592254   TB      RHP           84
# 84       Beau       Burrows    663366  DET      RHP           85
# 85       Isan          Diaz    656371  MIA    2B/SS           86
# 86      Tyler       O'Neill    641933  STL       OF           87
# 87       Adam       Haseley    656514  PHI       OF           88
# 88     Austin          Hays    669720  BAL       OF           89
# 89   Harrison         Bader    664056  STL       OF           90
# 90       Alec        Hansen    641662  CWS      RHP           91
# 91     Miguel       Andujar    609280  NYY       3B           92
# 92    Michael        Chavis    656308  BOS       3B           93
# 93     Michel          Baez    673258   SD      RHP           94
# 94       Joey         Wentz    666214  ATL      LHP           95
# 95        Jon    Duplantier    641541  ARI      RHP           96
# 96     Corbin        Burnes    669203  MIL      RHP           97
# 97      Jorge         Mateo    622761  OAK    SS/OF           98
# 98     Carter       Kieboom    666198  WAS       SS           99
# 99      Jesse        Winker    608385  CIN       OF          100
#
#                                        Written Report
# 0   long considered the best player in the world n...
# 1   signed by the cubs for $1.7 million out of ven...
# 2   signed for $225,000 out of the dominican repub...
# 3   the blue jays traded a pair of prospects in ex...
# 4   after signing for $2.8 million out of the domi...
# 5   acuna made his united states debut in 2015, ho...
# 6   mlbpipeline.com's top-rated prospect and the f...
# 7   the astros gave $4 million bonuses to two high...
# 8   senzel first started to raise his profile in t...
# 9   signed by the red sox for $1.5 million as the ...
# 10  buehler entered 2015 as the top-rated prospect...
# 11  honeywell was anything but a known commodity i...
# 12  the rangers gave brinson a $1.625 million bonu...
# 13  originally signed out of the dominican republi...
# 14  reyes had put his 50-game suspension for marij...
# 15  adames was anything but a known commodity when...
# 16  since being a top 10 pick back in 2013, meadow...
# 17   rated as the top overall talent in the 2017 d...
# 18  having developed several pitchers drafted as h...
# 19  regarded as the best two-way draft prospect si...
# 20  mckenzie was dominant as a senior at royal pal...
# 21  since slipping to the middle of the first roun...
# 22  the most touted cuban prospect since yoan monc...
# 23  verdugo was a high school left-hander with a f...
# 24  whiteville (n.c.) hs had a nice draft run in t...
# 25  bichette's baseball bloodlines run deep. he's ...
# 26  the top high school position player in the 201...
# 27  a cousin of former big leaguer willy taveras, ...
# 28  hailing from the southern california high scho...
# 29  with steady infield skills and mlb bloodlines,...
# ..                                                ...
# 70  after missing two full seasons with an elbow i...
# 71  the red sox landed espinoza for $1.8 million d...
# 72  bauers' impressive full-season debut in 2014 c...
# 73  kendall could have been a top-three-rounds pic...
# 74  bukauskas burst on the scoring radar early in ...
# 75  a talented two-way player from the texas high ...
# 76  diaz starred as an 18-year-old in cuba's top l...
# 77  the younger brother of angels right-hander gre...
# 78  then known as haniel de oleo, an identity he a...
# 79  clint frazier wasn't the only former first-rou...
# 80  woodruff honored his commitment to mississippi...
# 81  college bats are often hard to find, especiall...
# 82  since signing with the mariners out of brazil ...
# 83  de leon was recruited by one school (southern)...
# 84  the tigers have not shied away from taking hig...
# 85  the d-backs selected diaz 70th overall in the ...
# 86  the mariners made o'neill their third-round pi...
# 87   haseley was a two-way standout at virginia, p...
# 88   hays starred as a freshman at seminole state ...
# 89  the cardinals have shown a knack over the year...
# 90  based on early returns, hansen could be the st...
# 91  the highest-priced signee in the yankees' 2011...
# 92  chavis hit his way into the first round of the...
# 93  the padres landed baez during their internatio...
# 94  when the braves signed their top pick ian ande...
# 95   duplantier missed his sophomore season at ric...
# 96  coming off of a strong showing in the 2015 cap...
# 97  mateo began 2016 as the yankees' top-rated pro...
# 98  it goes without saying that the kieboom family...
# 99  a product of olympia high school in orlando, a...
#
# [100 rows x 7 columns]

# %%
###2016

###Part 1: scraping initial 2019 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url_2016 = 'http://m.mlb.com/gen/players/prospects/2016/playerProspects.json'
response_2016 = requests.get(mlb_json_id_url_2016)
response_2016.status_code
all_json_2016 = response_2016.json()
prospect_list_2016 = all_json_2016['prospect_players']['prospects']
player_ids_2016 = []
player_ranks_2016 = []
player_first_name_2016 = []
player_last_name_2016 = []
player_position_2016 = []
player_team_2016 = []
for i in prospect_list_2016:
    player_id = str(i['player_id'])
    player_ids_2016.append(player_id)                      
    rank = i["rank"]
    player_ranks_2016.append(rank)
    first_name = i["player_first_name"]
    player_first_name_2016.append(first_name)
    last_name = i["player_last_name"]
    player_last_name_2016.append(last_name)
    position = i["position"]
    player_position_2016.append(position)
    team = i["team_file_code"]
    player_team_2016.append(team)
    player_id_data_2016 = {'First Name' : player_first_name_2016, 'Last Name' : player_last_name_2016, 'Player ID' : player_ids_2016, 'Team' : player_team_2016, 'Position' : player_position_2016, 'Player Rank' : player_ranks_2016}


player_id_dataframe_2016 = pd.DataFrame(player_id_data_2016)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2016/"
prospect_url_list_2016 = []
link_status_2016 = []
#testing links
for i in player_ids_2016:
    prospect_url = pipeline_url + i + '.json'
    prospect_url_list_2016.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2016.append(link)
    
#making initial list of player scout-reports/cards
card_list_2016 = []
for i in prospect_url_list_2016:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    card_list_2016.append(player_report)



report_trim_1_list_2016 = []
for i in card_list_2016:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    report_trim_1_list_2016.append(report_trim_1)

report_cleaner_list_2016 = []
for i in report_trim_1_list_2016:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    report_cleaner_list_2016.append(trim_a)

reports_2016 = []
for i in report_cleaner_list_2016:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    lowered = without_n.lower()
    reports_2016.append(lowered)

player_id_dataframe_2016['Written Report'] = reports_2016
top_one_hundred_data_2016 = player_id_dataframe_2016

top_one_hundred_data_2016
# Out:
#    First Name   Last Name Player ID Team Position  Player Rank  \
# 0        Yoan     Moncada    660162  CWS       2B            1
# 1        J.P.    Crawford    641487  PHI       SS            2
# 2       Lucas     Giolito    608337  CWS      RHP            3
# 3      Dansby     Swanson    621020  ATL       SS            4
# 4      Andrew  Benintendi    643217  BOS       OF            5
# 5     Brendan     Rodgers    663898  COL    SS/2B            6
# 6        Alex       Reyes    621052  STL      RHP            7
# 7       Tyler     Glasnow    607192  PIT      RHP            8
# 8      Austin     Meadows    640457  PIT       OF            9
# 9      Victor      Robles    645302  WAS       OF           10
# 10       Amed     Rosario    642708  NYM       SS           11
# 11      Ozzie      Albies    645277  ATL    SS/2B           12
# 12   Anderson    Espinoza    659262   SD      RHP           13
# 13      Lewis     Brinson    621446  MIL       OF           14
# 14      Clint     Frazier    640449  NYY       OF           15
# 15     Rafael      Devers    646240  BOS       3B           16
# 16    Gleyber      Torres    650402  NYY       SS           17
# 17      Jorge       Mateo    622761  NYY    SS/2B           18
# 18      Willy      Adames    642715   TB       SS           19
# 19       Josh        Bell    605137  PIT       1B           20
# 20        Ian        Happ    664023  CHC       2B           21
# 21      Aaron       Judge    592450  NYY       OF           22
# 22       Eloy     Jimenez    650391  CHC       OF           23
# 23     Mickey      Moniak    666160  PHI       OF           24
# 24    Bradley      Zimmer    605548  CLE       OF           25
# 25      Manny      Margot    622534   SD       OF           26
# 26      Corey         Ray    641999  MIL       OF           27
# 27       Kyle       Lewis    641786  SEA       OF           28
# 28    Francis      Martes    642564  HOU      RHP           29
# 29    Michael      Kopech    656629  CWS      RHP           30
# ..        ...         ...       ...  ...      ...          ...
# 70     Raimel       Tapia    606132  COL       OF           71
# 71      Mitch      Keller    656605  PIT      RHP           72
# 72       Jake      Bauers    641343   TB    OF/1B           73
# 73    Richard       Urena    620446  TOR       SS           74
# 74      Erick       Fedde    607200  WAS      RHP           75
# 75       Sean  Reid-Foley    656887  TOR      RHP           76
# 76        Ian    Anderson    666120  ATL      RHP           77
# 77     Justus   Sheffield    656954  NYY      LHP           78
# 78  Christian      Arroyo    624414   SF      INF           79
# 79       Zack     Collins    641470  CWS        C           80
# 80       Luke      Weaver    596133  STL      RHP           81
# 81     Albert      Almora    546991  CHC       OF           82
# 82   Harrison       Bader    664056  STL       OF           83
# 83      Derek      Fisher    605233  HOU       OF           84
# 84  Francisco       Mejia    642336  CLE        C           85
# 85    Stephen   Gonsalves    624427  MIN      LHP           86
# 86    Anthony      Alford    546990  TOR       OF           87
# 87     Willie     Calhoun    641432  LAD       2B           88
# 88       Josh      Naylor    647304   SD       1B           89
# 89      Kevin      Maitan    670867  ATL       SS           90
# 90       Mike      Soroka    647336  ATL      RHP           91
# 91     Yadier     Alvarez    665751   LA      RHP           92
# 92       Alex   Kirilloff    666135  MIN       OF           93
# 93    Yusniel        Diaz    666783   LA       OF           94
# 94       Matt     Chapman    656305  OAK       3B           95
# 95    Triston    McKenzie    663474  CLE      RHP           96
# 96       Isan        Diaz    656371  MIL    SS/2B           97
# 97      Dylan       Cease    656302  CHC      RHP           98
# 98      Tyler       Beede    595881   SF      RHP           99
# 99     Jeimer  Candelario    600869  CHC       3B          100
#
#                                        Written Report
# 0   the most-hyped teenaged prospect to come out o...
# 1   four high school hitters were taken before cra...
# 2   scouts viewed giolito as the top prep hurler a...
# 3   for now, swanson is known as the first no. 1 o...
# 4   the ohio state division iii baseball and baske...
# 5   mlbpipeline.com's top-rated prospect in the 20...
# 6   ever since reyes joined the cardinals organiza...
# 7   at various times since neal huntington took ov...
# 8   one of two high school hitters taken in the fi...
# 9   robles has done nothing but impress since the ...
# 10  since rosario made his pro debut in 2013 after...
# 11  just about everything went right for albies du...
# 12  yoan moncada wasn't the only potential star th...
# 13  brinson's impressive raw tools got him drafted...
# 14  the first high school position player selected...
# 15  scouts considered devers the best left-handed ...
# 16  addison russell was barely 21 when he cracked ...
# 17  mateo didn't generate any headlines when he si...
# 18  signed by the tigers out of the dominican repu...
# 19  the pirates gave bell $5 million to sign out o...
# 20  the cubs believe in taking college hitters wit...
# 21  at 6-foot-7 and 275 pounds, judge looks like h...
# 22  the top-rated prospect on the 2013 internation...
# 23  a strong performance on the summer showcase ci...
# 24  zimmer's older brother, kyle, was drafted fift...
# 25  one of the top athletes in the 2011 internatio...
# 26  ray ranked as the draft's top position prospec...
# 27  lewis went undrafted out of a georgia high sch...
# 28  the astros scout the lower levels of the minor...
# 29  signed for $1.5 million as the 33rd overall pi...
# ..                                                ...
# 70  signed for $175,000 out of the dominican in 20...
# 71  the pirates loved keller coming out of the iow...
# 72  acquired from the padres last offseason in the...
# 73  the blue jays opened the 2012 international pe...
# 74  fedde was viewed as a potential top 10 pick in...
# 75  reid-foley emerged as a potential first-round ...
# 76  ranked no. 13 on mlbpipeline.com's top 200 dra...
# 77  the indians used their second of two first-rou...
# 78  most teams didn't evaluate arroyo as a first-r...
# 79  collins has a track record of hitting that dat...
# 80  in his junior season at florida state, weaver'...
# 81  almora had the reputation of being one of the ...
# 82  the last time the cardinals took a full-time c...
# 83  few players in the 2014 draft could match fish...
# 84  the indians signed mejia out of the dominican ...
# 85  after slipping to the fourth round of the 2013...
# 86  teams viewed alford as a tough sign heading in...
# 87  after going homerless as an arizona freshman i...
# 88  naylor became the highest-drafted canadian hit...
# 89  ranked no. 1 on mlbpipeline.com's top 30 inter...
# 90  the canadian junior national team annually hea...
# 91  the dodgers went all-in on the international m...
# 92  a strong summer showcase circuit showing put k...
# 93  as an 18-year-old in cuba's top league, the se...
# 94  chapman starred at cal state fullerton for thr...
# 95  after a dominant senior season at royal palm b...
# 96  the d-backs selected diaz 70th overall in the ...
# 97  as one of the best high school power arms in t...
# 98  one of 20 players in draft history to get sele...
# 99  even after the starlin castro trade, the cubs ...
#
# [100 rows x 7 columns]

# %%
###2014

###Part 1: scraping initial 2014 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url_2014 = 'http://m.mlb.com/gen/players/prospects/2014/playerProspects.json'
response_2014 = requests.get(mlb_json_id_url_2014)
response_2014.status_code
all_json_2014 = response_2014.json()
prospect_list_2014 = all_json_2014['prospect_players']['prospects']
player_ids_2014 = []
player_ranks_2014 = []
player_first_name_2014 = []
player_last_name_2014 = []
player_position_2014 = []
player_team_2014 = []
for i in prospect_list_2014:
    player_id = str(i['player_id'])
    player_ids_2014.append(player_id)                      
    rank = i["rank"]
    player_ranks_2014.append(rank)
    first_name = i["player_first_name"]
    player_first_name_2014.append(first_name)
    last_name = i["player_last_name"]
    player_last_name_2014.append(last_name)
    position = i["position"]
    player_position_2014.append(position)
    team = i["team_file_code"]
    player_team_2014.append(team)
    player_id_data_2014 = {'First Name' : player_first_name_2014, 'Last Name' : player_last_name_2014, 'Player ID' : player_ids_2014, 'Team' : player_team_2014, 'Position' : player_position_2014, 'Player Rank' : player_ranks_2014}


player_id_dataframe_2014 = pd.DataFrame(player_id_data_2014)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2014/"
prospect_url_list_2014 = []
link_status_2014 = []
#testing links
for i in player_ids_2014:
    prospect_url = pipeline_url + i + '.json'
    prospect_url_list_2014.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2014.append(link)
    
#making initial list of player scout-reports/cards
card_list_2014 = []
for i in prospect_url_list_2014:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    card_list_2014.append(player_report)



report_trim_1_list_2014 = []
for i in card_list_2014:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    report_trim_1_list_2014.append(report_trim_1)

report_cleaner_list_2014 = []
for i in report_trim_1_list_2014:
    if i.find('</a>') == -1:
        start = i.find('n<p>') + 3
    else:
        start = i.find('</a>') + 8
    trim_a = i[start:]
    report_cleaner_list_2014.append(trim_a)

reports_2014 = []
for i in report_cleaner_list_2014:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    without_slash = without_n.replace('/', '')
    lowered = without_slash.lower()
    reports_2014.append(lowered)

player_id_dataframe_2014['Written Report'] = reports_2014
top_one_hundred_data_2014 = player_id_dataframe_2014

top_one_hundred_data_2014
# Out:
#    First Name    Last Name Player ID Team Position  Player Rank  \
# 0       Byron       Buxton    621439  MIN       OF            1
# 1      Carlos       Correa    621043  HOU       SS            2
# 2        Kris       Bryant    592178  CHC       3B            3
# 3   Francisco       Lindor    596019  CLE       SS            4
# 4     Addison      Russell    608365  CHC       SS            5
# 5        Joey        Gallo    608336  TEX       3B            6
# 6      Miguel         Sano    593934  MIN       3B            7
# 7       Lucas      Giolito    608337  WAS      RHP            8
# 8      Archie      Bradley    605151  ARI      RHP            9
# 9        Noah  Syndergaard    592789  NYM      RHP           10
# 10        Jon         Gray    592351  COL      RHP           11
# 11      Dylan        Bundy    605164  BAL      RHP           12
# 12      Corey       Seager    608369   LA       SS           13
# 13      Julio        Urias    628711   LA      LHP           14
# 14        Joc     Pederson    592626   LA       OF           15
# 15      Tyler      Glasnow    607192  PIT      RHP           16
# 16     Robert   Stephenson    596112  CIN      RHP           17
# 17     Andrew       Heaney    571760  ANA      LHP           18
# 18     Carlos        Rodon    607074  CWS      LHP           19
# 19      Henry        Owens    596064  BOS      LHP           20
# 20       Kohl      Stewart    640464  MIN      RHP           21
# 21     Austin       Hedges    595978   SD        C           22
# 22      Tyler        Kolek    656626  MIA      RHP           23
# 23      Blake      Swihart    596119  BOS        C           24
# 24     Daniel       Norris    596057  TOR      LHP           25
# 25      Eddie       Butler    572750  COL      RHP           26
# 26       Alex        Meyer    543542  MIN      RHP           27
# 27    Jameson      Taillon    592791  PIT      RHP           28
# 28       Josh         Bell    605137  PIT       OF           29
# 29      Jorge       Alfaro    595751  TEX     C/1B           30
# ..        ...          ...       ...  ...      ...          ...
# 70     Hunter      Renfroe    592669   SD       OF           71
# 71       Kyle    Schwarber    656941  CHC     C/OF           72
# 72       Alen       Hanson    593700  PIT       SS           73
# 73      Reese      McGuire    624512  PIT        C           74
# 74    Anthony      Ranaudo    519168  BOS      RHP           75
# 75      Lance    McCullers    621121  HOU      RHP           76
# 76  Christian  Bethancourt    542194  ATL        C           77
# 77      Touki    Toussaint    657053  ARI      RHP           78
# 78    Michael     Conforto    624424  NYM       OF           79
# 79      Aaron        Blair    594760  ARI      RHP           80
# 80    Dominic        Smith    642086  NYM       1B           81
# 81        Tim     Anderson    641313  CWS       SS           82
# 82       Sean      Newcomb    656794  ANA      LHP           83
# 83       Nick     Williams    608384  TEX       OF           84
# 84     Daniel    Robertson    621002  OAK       SS           85
# 85     Hunter       Dozier    641531   KC       3B           86
# 86     Miguel      Almonte    602083   KC      RHP           87
# 87     Dalton       Pompey    592647  TOR       OF           88
# 88     Raimel        Tapia    606132  COL       OF           89
# 89       Jeff      Hoffman    656546  TOR      RHP           90
# 90       Jake         Lamb    571875  ARI       3B           91
# 91    Michael        Feliz    593140  HOU      RHP           92
# 92       Alex     Gonzalez    592346  TEX      RHP           93
# 93        Rob     Kaminsky    641739  STL      LHP           94
# 94     Rafael      Montero    606160  NYM      RHP           95
# 95       Trea       Turner    607208   SD       SS           96
# 96    Brandon     Finnegan    605232   KC      LHP           97
# 97    Matthew        Olson    621566  OAK       1B           98
# 98      Marco     Gonzales    594835  STL      LHP           99
# 99      Grant       Holmes    656550   LA      RHP          100
#
#                                        Written Report
# 0   buxton took the minor leagues by storm in his ...
# 1   in a draft class that also included byron buxt...
# 2   bryant began his incredible run in 2013 by win...
# 3   lindor has been on the fast track since the in...
# 4   russell rose up first-year player draft boards...
# 5    gallo set the nevada high school career recor...
# 6   sano was in the spotlight even before he signe...
# 7   giolito was considered to be the top prep pitc...
# 8   br ><br >the d-backs had two of the first seve...
# 9   after being acquired by the mets in the <span ...
# 10  gray didn't enter the spring of 2013 with much...
# 11  bundy was so advanced as a prep star in oklaho...
# 12  the dodgers took seager -- the younger brother...
# 13  the dodgers signed urias as a 16-year-old out ...
# 14  while pederson was overshadowed at the start o...
# 15  the pirates have been cautious with glasnow, b...
# 16  the reds were cautious at first with stephenso...
# 17  drafted as a potentially quick-to-the-big-leag...
# 18  the best college left-hander since <span class...
# 19  owens was dinged for his perceived lack of pro...
# 20  a two-sport star in high school, stewart was c...
# 21  even coming out of high school, hedges was kno...
# 22  an>, kolek's combination of size and stuff mad...
# 23  the red sox were initially attracted to swihar...
# 24  though the blue jays didn't sign 2011 first ro...
# 25  butler came on strong in the second half of hi...
# 26  in his first season with the twins after joini...
# 27  taillon was sandwiched between <span class="to...
# 28  bell was believed to be unsignable going into ...
# 29   after injuries limited him to just 29 games b...
# ..                                                ...
# 70  as a high schooler in mississippi, renfroe was...
# 71  undrafted and relatively unknown coming out of...
# 72  hanson was one of the pirates' breakout prospe...
# 73  after selecting meadows in the 2013 draft, the...
# 74  ranaudo won the college world series champions...
# 75  nbsp;<mccullers was considered one of the top ...
# 76   a native of panama, bethancourt has been a fi...
# 77  toussaint spent most of the first six years of...
# 78  conforto has athletic bloodlines, as his fathe...
# 79  blair led the cape cod league with a 1.17 era ...
# 80  smith was thought to be the best pure high sch...
# 81  undrafted out of high school and after his fir...
# 82  when the angels took newcomb with the 15th pic...
# 83  williams was the most natural hitter on a low ...
# 84  the rays bolstered their system by acquiring t...
# 85  dozier was one of the top performers among the...
# 86  after just 27 innings in the united states, th...
# 87  a broken hand limited pompey in 2012, but he b...
# 88  when a dominican teenager comes and makes his ...
# 89  after a strong showing in the cape cod league ...
# 90  though he had a solid career at washington, la...
# 91  nbsp;<originally signed by the a's as a 16-yea...
# 92  the best prospect to come out of oral roberts ...
# 93  st. louis has cleaned up in recent years with ...
# 94  montero was already 20 years old when he signe...
# 95  turner teamed with left-hander carlos rodon at...
# 96  one of the better college lefties in the draft...
# 97  a highly regarded two-way player coming out of...
# 98  gonzales swung a nice line-drive bat, and he p...
# 99  holmes has much more power in his arsenal than...
#
# [100 rows x 7 columns]

# %%
###2013

###Part 1: scraping initial 2013 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url_2013 = 'http://m.mlb.com/gen/players/prospects/2013/playerProspects.json'
response_2013 = requests.get(mlb_json_id_url_2013)
response_2013.status_code
all_json_2013 = response_2013.json()
prospect_list_2013 = all_json_2013['prospect_players']['prospects']
player_ids_2013 = []
player_ranks_2013 = []
player_first_name_2013 = []
player_last_name_2013 = []
player_position_2013 = []
player_team_2013 = []
for i in prospect_list_2013:
    player_id = str(i['player_id'])
    player_ids_2013.append(player_id)                      
    rank = i["rank"]
    player_ranks_2013.append(rank)
    first_name = i["player_first_name"]
    player_first_name_2013.append(first_name)
    last_name = i["player_last_name"]
    player_last_name_2013.append(last_name)
    position = i["position"]
    player_position_2013.append(position)
    team = i["team_file_code"]
    player_team_2013.append(team)
    player_id_data_2013 = {'First Name' : player_first_name_2013, 'Last Name' : player_last_name_2013, 'Player ID' : player_ids_2013, 'Team' : player_team_2013, 'Position' : player_position_2013, 'Player Rank' : player_ranks_2013}


player_id_dataframe_2013 = pd.DataFrame(player_id_data_2013)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2013/"
prospect_url_list_2013 = []
link_status_2013 = []
#testing links
for i in player_ids_2013:
    prospect_url = pipeline_url + i + '.json'
    prospect_url_list_2013.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2013.append(link)
    
#making initial list of player scout-reports/cards
card_list_2013 = []
for i in prospect_url_list_2013:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    card_list_2013.append(player_report)



report_trim_1_list_2013 = []
for i in card_list_2013:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    report_trim_1_list_2013.append(report_trim_1)

report_cleaner_list_2013 = []
for i in report_trim_1_list_2013:
    start = i.find('<p>') + 3
    trim_p = i[start:]
    report_cleaner_list_2013.append(trim_p)
    
report_cleanest_list_2013 = []
for i in report_cleaner_list_2013:
    if i.find('</a>') == -1:
          end = len(i)
    else:
        end = i.find('\n<p>\n')
    trim_a = i[:end]
    report_cleanest_list_2013.append(trim_a)
    
reports_2013 = []
for i in report_cleanest_list_2013:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    without_slash = without_n.replace('/', '')
    without_tag = without_slash.replace('&#8217;', "'")
    without_tag2 = without_tag.replace(' &#8211;', ",")
    without_tag3 = without_tag2.replace('&rsquo;', "'")
    lowered = without_tag3.lower()
    reports_2013.append(lowered)

player_id_dataframe_2013['Written Report'] = reports_2013
top_one_hundred_data_2013 = player_id_dataframe_2013
top_one_hundred_data_2013
# Out:
#    First Name    Last Name Player ID Team Position  Player Rank  \
# 0       Byron       Buxton    621439  MIN       OF            1
# 1       Oscar      Taveras    570805  STL       OF            2
# 2      Miguel         Sano    593934  MIN       3B            3
# 3     Taijuan       Walker    592836  SEA      RHP            4
# 4   Francisco       Lindor    596019  CLE       SS            5
# 5      Xander     Bogaerts    593428  BOS       SS            6
# 6      Archie      Bradley    605151  ARI      RHP            7
# 7      Carlos       Correa    621043  HOU       SS            8
# 8      Javier         Baez    595879  CHC       SS            9
# 9     Jameson      Taillon    592791  PIT      RHP           10
# 10       Nick  Castellanos    592206  DET       OF           11
# 11       Noah  Syndergaard    592789  NYM      RHP           12
# 12    Gregory      Polanco    570256  PIT       OF           13
# 13      Kevin      Gausman    592332  BAL      RHP           14
# 14      Dylan        Bundy    605164  BAL      RHP           15
# 15      Billy     Hamilton    571740  CIN       OF           16
# 16     Robert   Stephenson    596112  CIN      RHP           17
# 17    Addison      Russell    608365  OAK       SS           18
# 18   Jonathan    Singleton    572138  HOU       1B           19
# 19     Travis     d'Arnaud    518595  NYM        C           20
# 20      Aaron      Sanchez    592717  TOR      RHP           21
# 21     Albert       Almora    546991  CHC       OF           22
# 22     George     Springer    543807  HOU       OF           23
# 23      Danny      Hultzen    543343  SEA      LHP           24
# 24       Mark        Appel    571446  HOU      RHP           25
# 25      Jorge        Soler    624585  CHC       OF           26
# 26       Gary      Sanchez    596142  NYY        C           27
# 27     Jackie      Bradley    598265  BOS       OF           28
# 28     Taylor    Guerrieri    605260   TB      RHP           29
# 29       Kyle       Zimmer    622092   KC      RHP           30
# ..        ...          ...       ...  ...      ...          ...
# 70       Luis     Sardinas    596143  TEX       SS           71
# 71      Colin        Moran    592567  MIA       3B           72
# 72     Maikel       Franco    596748  PHI       3B           73
# 73     Delino    DeShields    592261  HOU       2B           74
# 74     Hak-Ju          Lee    573349   TB       SS           75
# 75       Luis      Heredia    599093  PIT      RHP           76
# 76       Jose      Berrios    621244  MIN      RHP           77
# 77      Kaleb       Cowart    592230  ANA       3B           78
# 78      Rymer      Liriano    542642   SD       OF           79
# 79    Anthony      Ranaudo    519168  BOS      RHP           80
# 80       A.J.         Cole    595918  WAS      RHP           81
# 81       Alex       Colome    517008   TB      RHP           82
# 82      Garin     Cecchini    594555  BOS       3B           83
# 83      Chris       Owings    572008  ARI       SS           84
# 84    Eduardo    Rodriguez    593958  BAL      LHP           85
# 85       Trey         Ball    640441  BOS      LHP           86
# 86      Jimmy       Nelson    519076  MIL      RHP           87
# 87      Eddie       Butler    572750  COL      RHP           88
# 88      Julio        Urias    628711   LA      LHP           89
# 89      Jorge    Bonifacio    593528   KC       OF           90
# 90    Michael       Choice    574831  TEX       OF           91
# 91     Marcus      Stroman    573186  TOR      RHP           92
# 92      Lucas         Sims    608371  ATL      RHP           93
# 93    Clayton    Blackburn    607185   SF      RHP           94
# 94    Dorssys      Paulino    609267  CLE       SS           95
# 95    Rougned         Odor    596059  TEX       2B           96
# 96      Tyler      Glasnow    607192  PIT      RHP           97
# 97     Rafael      Montero    606160  NYM      RHP           98
# 98     Rafael     De Paula    606127  NYY      RHP           99
# 99      Roman        Quinn    596451  PHI       SS          100
#
#                                        Written Report
# 0    while carlos correa was a deserving choice fo...
# 1    the st. louis cardinals have developed some a...
# 2    sano has been in the spotlight since signing ...
# 3    the mariners didn't have a first-round pick i...
# 4    any baseball field lindor is on, he looks lik...
# 5    the aruba native and 2012 futures game partic...
# 6    by all accounts, bradley's first full season ...
# 7    don't think the selection of correa as the to...
# 8    when two high school shortstops are taken one...
# 9    pirates fans who are eagerly anticipating the...
# 10   ever since the tigers took him and gave him a...
# 11  syndergaard has dominated professional hitters...
# 12   there were few prospects in all of the minor ...
# 13   what a difference two years can make. coming ...
# 14   it's not often that a pitcher makes it to the...
# 15  it's not often that a player with hamilton's e...
# 16   for two years in a row, the reds went with a ...
# 17   russell's conditioning and future position ha...
# 18   the top first base prospect in the game, sing...
# 19   d'arnaud has been snakebitten the past two ye...
# 20   if you wanted to build a prototype of what a ...
# 21   byron buxton got most of the buzz as the tool...
# 22   power and speed. it's a combination always in...
# 23   hultzen's first full season of pro ball was a...
# 24   appel was considered by many to be one of the...
# 25   three cuban outfielders signed big contracts ...
# 26   sanchez has been on radars since the yankees ...
# 27   a subpar junior season at south carolina, whi...
# 28   guerrieri jumped into the first round of the ...
# 29   typically, amateurs who are new to pitching a...
# ..                                                ...
# 70   he's not going to cause any kind of logjam wi...
# 71  moran re-established the university of north c...
# 72   franco proved himself in his full-season debu...
# 73   sometimes repeating a level isn't such a bad ...
# 74   lee's name has been on prospect radars for qu...
# 75   since signing out of mexico, heredia has been...
# 76   the top arm coming out of puerto rico, berrio...
# 77   mark trumbo and mike trout are in the big lea...
# 78  liriano should develop into a prototypical rig...
# 79  it hasn't been the easiest road for ranaudo, t...
# 80   it often takes time for those high-ceilinged,...
# 81  rays fans should get ready for another colome ...
# 82   so that's what all the fuss was about. the re...
# 83   repeating a level can be a good thing for a y...
# 84  it's amazing what growth and maturity can do f...
# 85  the top two-way player in the draft class of 2...
# 86   nelson began the 2012 season in a prospect-la...
# 87   a strong finish to his junior season at radfo...
# 88  the dodgers signed urias out of mexico in augu...
# 89   jorge's brother, emilio, is in the big league...
# 90   oakland's first-round pick in 2010, choice wa...
# 91  it was difficult enough to evaluate stroman co...
# 92   the braves stayed in their own backyard for t...
# 93  as a teenager in the full-season south atlanti...
# 94   the indians gave paulino, the son of former b...
# 95   the venezuelan infielder should not be overlo...
# 96  the pirates have been very cautious with glasn...
# 97   since signing out of the dominican republic a...
# 98  de paula first appeared as a prospect in 2008 ...
# 99   there is no one in the phillies' system with ...
#
# [100 rows x 7 columns]

# %%
###2012

###Part 1: scraping initial 2012 mlb pipeline json file for player ID dataframe
import pandas as pd
import requests
#making initial broad datarfame
mlb_json_id_url_2012 = 'http://m.mlb.com/gen/players/prospects/2012/playerProspects.json'
response_2012 = requests.get(mlb_json_id_url_2012)
response_2012.status_code
all_json_2012 = response_2012.json()
prospect_list_2012 = all_json_2012['prospect_players']['prospects']
player_ids_2012 = []
player_ranks_2012 = []
player_first_name_2012 = []
player_last_name_2012 = []
player_position_2012 = []
player_team_2012 = []
for i in prospect_list_2012:
    player_id = str(i['player_id'])
    player_ids_2012.append(player_id)                      
    rank = i["rank"]
    player_ranks_2012.append(rank)
    first_name = i["player_first_name"]
    player_first_name_2012.append(first_name)
    last_name = i["player_last_name"]
    player_last_name_2012.append(last_name)
    position = i["position"]
    player_position_2012.append(position)
    team = i["team_file_code"]
    player_team_2012.append(team)
    player_id_data_2012 = {'First Name' : player_first_name_2012, 'Last Name' : player_last_name_2012, 'Player ID' : player_ids_2012, 'Team' : player_team_2012, 'Position' : player_position_2012, 'Player Rank' : player_ranks_2012}


player_id_dataframe_2012 = pd.DataFrame(player_id_data_2012)


###Part 3: Scraping every Top100 report into dataframes
pipeline_url = "http://m.mlb.com/gen/players/prospects/2012/"
prospect_url_list_2012 = []
link_status_2012 = []
#testing links
for i in player_ids_2012:
    prospect_url = pipeline_url + i + '.json'
    prospect_url_list_2012.append(prospect_url)
    if response.status_code == 200:
        link = 'Link is working'
    else:
        link = 'Link does not work'
    link_status_2012.append(link)
    
#making initial list of player scout-reports/cards
card_list_2012 = []
for i in prospect_url_list_2012:    
    response = requests.get(i)
    player_card_framed = response.json()
    player_card = player_card_framed['prospect_player']
    player_card
    player_report_and_video = player_card['content']
    player_report = player_report_and_video['default']
    card_list_2012.append(player_report)



report_trim_1_list_2012 = []
for i in card_list_2012:
    trim = i.rfind('Overall: ') + 10
    report_trim_1 = i[trim:]
    report_trim_1_list_2012.append(report_trim_1)

report_cleaner_list_2012 = []
for i in report_trim_1_list_2012:
    start = i.find('<p>') + 3
    trim_p = i[start:]
    report_cleaner_list_2012.append(trim_p)
    
report_cleanest_list_2012 = []
for i in report_cleaner_list_2012:
    if i.find('</a>') == -1:
          end = len(i)
    else:
        end = i.find('\n<p>\n')
    trim_a = i[:end]
    report_cleanest_list_2012.append(trim_a)
    
reports_2012 = []
for i in report_cleanest_list_2012:
    without_p = i.replace('<p>', '')
    without_p2 = without_p.replace('p>', '')
    without_n = without_p2.replace('\n', '')
    without_slash = without_n.replace('/', '')
    without_tag = without_slash.replace('&#8217;', "'")
    without_tag2 = without_tag.replace(' &#8211;', ",")
    without_tag3 = without_tag2.replace('&rsquo;', "'")
    lowered = without_tag3.lower()
    reports_2012.append(lowered)

player_id_dataframe_2012['Written Report'] = reports_2012
top_one_hundred_data_2012 = player_id_dataframe_2012

top_one_hundred_data_2012
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-8-35440fa8aff4> in <module>
#      53 for i in prospect_url_list_2012:
#      54     response = requests.get(i)
# ---> 55     player_card_framed = response.json()
#      56     player_card = player_card_framed['prospect_player']
#      57     player_card
#
# ~/anaconda3_501/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3_501/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3_501/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3_501/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
